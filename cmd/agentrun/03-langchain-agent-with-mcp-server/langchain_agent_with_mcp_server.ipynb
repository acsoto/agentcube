# %% [markdown]
# # LangChain Agent with MCP Server Integration
#
# ## Overview
#
# In this tutorial, you will learn how to build and deploy a distributed AI agent system using:
# - **MCP Server**: A Model Context Protocol server providing utility tools
# - **LangChain Agent**: An agent that consumes and orchestrates MCP server tools
# - **AgentRun CLI**: To deploy both components separately to local Kubernetes
#
# This demonstrates a microservices architecture where the tool provider (MCP server) and the agent orchestrator (LangChain agent) are deployed and scaled independently.
#
# ### Tutorial Details
#
# | Information         | Details                                                                      |
# |:--------------------|:-----------------------------------------------------------------------------|
# | Tutorial type       | Advanced Integration                                                         |
# | Agent type          | LangChain Agent + MCP Server                                                 |
# | Framework           | LangChain + MCP + FastAPI                                                    |
# | Language            | Python 3.8+                                                                  |
# | Tutorial components | MCP server creation, LangChain integration, distributed deployment           |
# | Tutorial vertical   | Cross-vertical                                                               |
# | Example complexity  | Intermediate                                                                 |
# | Tools used          | AgentRun CLI, Docker, Kubernetes, LangChain, MCP                             |
#
# ### What You'll Learn
#
# * How to create an MCP server with multiple useful tools
# * How to integrate MCP servers with LangChain agents
# * How to deploy distributed agent systems using AgentRun CLI
# * How agents and tools can communicate across services
# * Best practices for microservices-based AI architectures
#
# ### Tutorial Architecture
#
# ```
# ┌─────────────────────────────────────────────────────────────┐
# │                    User Request                             │
# │                         │                                   │
# │                         ▼                                   │
# │            ┌────────────────────────┐                       │
# │            │  LangChain Agent       │                       │
# │            │  (Port 8080)           │                       │
# │            │                        │                       │
# │            │  - Receives prompts    │                       │
# │            │  - Orchestrates tools  │                       │
# │            │  - Returns responses   │                       │
# │            └────────────┬───────────┘                       │
# │                         │                                   │
# │                         │ HTTP/MCP                          │
# │                         ▼                                   │
# │            ┌────────────────────────┐                       │
# │            │  MCP Server            │                       │
# │            │  (Port 8000)           │                       │
# │            │                        │                       │
# │            │  Tools:                │                       │
# │            │  - Calculator          │                       │
# │            │  - File Operations     │                       │
# │            │  - DateTime Utils      │                       │
# │            └────────────────────────┘                       │
# │                                                              │
# │         Both deployed separately to Kubernetes              │
# └─────────────────────────────────────────────────────────────┘
# ```
#
# ### Key Features
#
# * **Distributed Architecture**: Agent and tools deployed separately
# * **MCP Protocol**: Standard protocol for tool communication
# * **LangChain Integration**: Seamless integration with LangChain ecosystem
# * **Multiple Tool Categories**: Calculator, file operations, and datetime utilities
# * **Production-Ready**: Deployed to Kubernetes with proper service discovery

# %% [markdown]
# ## Prerequisites
#
# Before starting this tutorial, ensure you have:
#
# * **Python 3.8+** installed
# * **Docker** installed and running
# * **Kubernetes** (Docker Desktop with Kubernetes enabled, or minikube)
# * **AgentRun CLI** installed
# * Basic understanding of:
#   - Python programming
#   - REST APIs
#   - LangChain agents (recommended)
#   - Model Context Protocol (MCP) basics (recommended)

# %% [markdown]
# ## Step 1: Install Dependencies
#
# First, let's install AgentRun CLI and verify it's working.

# %%
# Install AgentRun CLI
# %pip install -e ../ --quiet
# Out:
# WARNING: typer 0.20.0 does not provide the extra 'all'
# Note: you may need to restart the kernel to use updated packages.

# %%
# Verify installation
# !agentrun --version
# Out:
# AgentRun CLI version: 0.1.0

# %% [markdown]
# ## Step 2: Explore the MCP Server
#
# Let's examine the MCP server that provides utility tools.

# %%
# View MCP server structure
# !ls -la mcp_server/
# Out:
# total 32
# drwxr-xr-x  4 ym  staff   128 Nov 26 09:44 .
# drwxr-xr-x  8 ym  staff   256 Nov 26 09:44 ..
# -rw-r--r--  1 ym  staff  8215 Nov 26 09:44 main.py
# -rw-r--r--  1 ym  staff    73 Nov 26 09:44 requirements.txt

# %%
# View MCP server tools (first 100 lines)
# !head -100 mcp_server/main.py
# Out:
# """
# MCP Server with Utility Tools
#
# This MCP server provides a collection of useful tools:
# - Calculator: Perform mathematical calculations
# - File operations: Read, write, and list files in a workspace
# - DateTime utilities: Get current time, format dates, timezone conversions
#
# The server uses FastMCP with stateless HTTP transport for compatibility
# with AgentRun CLI deployment.
# """
#
# import os
# import json
# from datetime import datetime, timezone
# from pathlib import Path
# from typing import Optional
# from mcp.server.fastmcp import FastMCP
#
# # Initialize FastMCP server
# mcp = FastMCP(
#     name="utility-tools-server",
#     host="0.0.0.0",
#     port=8000,
#     stateless_http=True
# )
#
# # Create a workspace directory for file operations
# WORKSPACE_DIR = Path("/tmp/mcp_workspace")
# WORKSPACE_DIR.mkdir(exist_ok=True)
#
#
# # ============================================================================
# # Calculator Tools
# # ============================================================================
#
# @mcp.tool()
# def calculate(expression: str) -> str:
#     """
#     Evaluate a mathematical expression and return the result.
#
#     Args:
#         expression: A mathematical expression string (e.g., "2 + 2", "10 * 5 + 3")
#
#     Returns:
#         The result of the calculation as a string
#
#     Examples:
#         - calculate("5 + 3") -> "8"
#         - calculate("10 * (5 + 2)") -> "70"
#     """
#     try:
#         # Use eval with restricted globals for safety
#         result = eval(expression, {"__builtins__": {}}, {})
#         return f"Result: {result}"
#     except Exception as e:
#         return f"Error calculating expression: {str(e)}"
#
#
# @mcp.tool()
# def power(base: float, exponent: float) -> str:
#     """
#     Calculate base raised to the power of exponent.
#
#     Args:
#         base: The base number
#         exponent: The exponent to raise the base to
#
#     Returns:
#         The result of base^exponent
#
#     Examples:
#         - power(2, 3) -> "8.0"
#         - power(5, 2) -> "25.0"
#     """
#     try:
#         result = base ** exponent
#         return f"Result: {result}"
#     except Exception as e:
#         return f"Error calculating power: {str(e)}"
#
#
# # ============================================================================
# # File Operation Tools
# # ============================================================================
#
# @mcp.tool()
# def write_file(filename: str, content: str) -> str:
#     """
#     Write content to a file in the workspace.
#
#     Args:
#         filename: Name of the file to write
#         content: Content to write to the file
#
#     Returns:
#         Success message or error message
#
#     Examples:
#         - write_file("notes.txt", "Hello World") -> "Successfully wrote to notes.txt"

# %% [markdown]
# ### Understanding the MCP Server
#
# The MCP server provides **8 utility tools** across three categories:
#
# **Calculator Tools:**
# 1. `calculate`: Evaluate mathematical expressions (e.g., "2 + 2", "10 * 5")
# 2. `power`: Calculate base raised to exponent (e.g., power(2, 3) = 8)
#
# **File Operation Tools:**
# 3. `write_file`: Write content to a file in the workspace
# 4. `read_file`: Read content from a file
# 5. `list_files`: List all files in the workspace
#
# **DateTime Tools:**
# 6. `get_current_time`: Get current date and time (with timezone support)
# 7. `format_timestamp`: Convert Unix timestamp to formatted date string
#
# **Info Tools:**
# 8. `server_info`: Get MCP server information
#
# The server uses:
# - **FastMCP**: Modern MCP server framework
# - **Stateless HTTP**: For compatibility with AgentRun deployment
# - **Port 8000**: Standard MCP server port

# %% [markdown]
# ## Step 3: Explore the LangChain Agent
#
# Now let's examine the LangChain agent that will consume the MCP server tools.

# %%
# View agent structure
# !ls -la agent/
# Out:
# total 40
# drwxr-xr-x  5 ym  staff    160 Nov 26 09:44 .
# drwxr-xr-x  8 ym  staff    256 Nov 26 09:44 ..
# -rw-r--r--  1 ym  staff    238 Nov 26 09:44 .env.example
# -rw-r--r--  1 ym  staff  12133 Nov 26 09:44 main.py
# -rw-r--r--  1 ym  staff    142 Nov 26 09:44 requirements.txt

# %%
# View agent code (first 80 lines)
# !head -80 agent/main.py
# Out:
# """
# LangChain Agent with MCP Server Integration
#
# This agent demonstrates how to integrate LangChain with an MCP server
# to provide enhanced tool-calling capabilities.
#
# The agent:
# - Connects to an MCP server via HTTP transport
# - Converts MCP tools to LangChain tools using langchain-mcp-adapters
# - Provides a FastAPI endpoint for user interaction
# - Can be deployed separately from the MCP server
#
# This showcases a microservices architecture for AI agents where:
# - MCP server provides the tools
# - LangChain agent orchestrates the tools
# - Both can be deployed and scaled independently
# """
#
# import os
# import asyncio
# from typing import Optional, Dict, Any, List
# from datetime import timedelta
#
# from fastapi import FastAPI, HTTPException
# from pydantic import BaseModel
# import uvicorn
#
# # LangChain imports
# from langchain.agents import AgentExecutor, create_react_agent
# from langchain_community.llms import OpenAI
# from langchain_core.prompts import PromptTemplate
# from langchain_core.tools import Tool
#
# # MCP imports
# from mcp import ClientSession
# from mcp.client.streamable_http import streamablehttp_client
#
# # langchain-mcp-adapters for converting MCP tools to LangChain tools
# try:
#     from langchain_mcp_adapters import convert_mcp_to_langchain_tools
# except ImportError:
#     # Fallback if the adapter doesn't exist, we'll create a simple converter
#     convert_mcp_to_langchain_tools = None
#
#
# # ============================================================================
# # Configuration
# # ============================================================================
#
# # MCP Server URL - can be configured via environment variable
# MCP_SERVER_URL = os.getenv("MCP_SERVER_URL", "http://localhost:8000/mcp")
# OPENAI_API_KEY = os.getenv("OPENAI_API_KEY", "")
# USE_MOCK_MODE = not OPENAI_API_KEY
#
# # Agent configuration
# AGENT_PORT = int(os.getenv("AGENT_PORT", "8080"))
#
#
# # ============================================================================
# # FastAPI App
# # ============================================================================
#
# app = FastAPI(
#     title="LangChain Agent with MCP Server",
#     description="An agent that integrates LangChain with MCP server tools",
#     version="1.0.0"
# )
#
#
# # ============================================================================
# # Request/Response Models
# # ============================================================================
#
# class AgentRequest(BaseModel):
#     prompt: str
#     temperature: Optional[float] = 0.7
#     max_tokens: Optional[int] = 500
#
#
# class AgentResponse(BaseModel):

# %% [markdown]
# ### Understanding the LangChain Agent
#
# The LangChain agent:
# - **Connects to MCP Server**: Uses MCP client to discover and call tools
# - **Converts MCP to LangChain**: Transforms MCP tools into LangChain-compatible tools
# - **Orchestrates Tool Calls**: Uses LangChain's ReAct agent to decide when and how to use tools
# - **Exposes REST API**: Provides FastAPI endpoints for interaction
#
# Key features:
# - **Mock Mode**: Works without OpenAI API key for testing
# - **Production Mode**: Uses OpenAI for real agent reasoning (when API key is set)
# - **Service Discovery**: Automatically connects to MCP server via environment variables
# - **Health Checks**: Provides health and status endpoints

# %% [markdown]
# ## Step 4: Test MCP Server Locally (Optional)
#
# Before deploying, let's test the MCP server locally to ensure it works.

# %%
# Install MCP server dependencies
# %pip install -r mcp_server/requirements.txt --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# Start MCP server in background
import subprocess
import time

mcp_proc = subprocess.Popen(
    ['python', 'mcp_server/main.py'],
    stdout=subprocess.PIPE,
    stderr=subprocess.PIPE
)

time.sleep(3)
print(f"MCP Server started (PID: {mcp_proc.pid})")
print("Server running on http://localhost:8000")
# Out:
# MCP Server started (PID: 26025)
# Server running on http://localhost:8000

# %%
# Test MCP server with a simple client
import asyncio
from datetime import timedelta
from mcp import ClientSession
from mcp.client.streamable_http import streamablehttp_client

async def test_mcp_server():
    mcp_url = "http://localhost:8000/mcp"
    headers = {}
    
    async with streamablehttp_client(mcp_url, headers, timeout=timedelta(seconds=30), terminate_on_close=False) as (
        read_stream, write_stream, _
    ):
        async with ClientSession(read_stream, write_stream) as session:
            await session.initialize()
            
            # List available tools
            tool_result = await session.list_tools()
            print("\n📋 Available Tools from MCP Server:")
            print("=" * 50)
            for tool in tool_result.tools:
                print(f"🔧 {tool.name}: {tool.description}")
            
            # Test calculator tool
            print("\n🧪 Testing Calculator Tool:")
            print("=" * 50)
            result = await session.call_tool(name="calculate", arguments={"expression": "15 + 27"})
            print(f"calculate('15 + 27') = {result.content[0].text}")
            
            # Test current time tool
            print("\n🕐 Testing DateTime Tool:")
            print("=" * 50)
            result = await session.call_tool(name="get_current_time", arguments={})
            print(f"get_current_time() = {result.content[0].text}")

try:
    await test_mcp_server()
    print("\n✅ MCP Server is working correctly!")
except Exception as e:
    print(f"\n❌ Error testing MCP server: {e}")
# Out:
# 📋 Available Tools from MCP Server:
# ==================================================
# 🔧 calculate:
#     Evaluate a mathematical expression and return the result.
#
#     Args:
#         expression: A mathematical expression string (e.g., "2 + 2", "10 * 5 + 3")
#
#     Returns:
#         The result of the calculation as a string
#
#     Examples:
#         - calculate("5 + 3") -> "8"
#         - calculate("10 * (5 + 2)") -> "70"
#
# 🔧 power:
#     Calculate base raised to the power of exponent.
#
#     Args:
#         base: The base number
#         exponent: The exponent to raise the base to
#
#     Returns:
#         The result of base^exponent
#
#     Examples:
#         - power(2, 3) -> "8.0"
#         - power(5, 2) -> "25.0"
#
# 🔧 write_file:
#     Write content to a file in the workspace.
#
#     Args:
#         filename: Name of the file to write
#         content: Content to write to the file
#
#     Returns:
#         Success message or error message
#
#     Examples:
#         - write_file("notes.txt", "Hello World") -> "Successfully wrote to notes.txt"
#
# 🔧 read_file:
#     Read content from a file in the workspace.
#
#     Args:
#         filename: Name of the file to read
#
#     Returns:
#         Content of the file or error message
#
#     Examples:
#         - read_file("notes.txt") -> "Hello World"
#
# 🔧 list_files:
#     List all files in the workspace directory.
#
#     Returns:
#         A list of files in the workspace
#
#     Examples:
#         - list_files() -> "Files in workspace: notes.txt, data.json"
#
# 🔧 get_current_time:
#     Get the current date and time.
#
#     Args:
#         timezone_name: Optional timezone name (e.g., "UTC", "US/Eastern")
#                       If not provided, returns UTC time
#
#     Returns:
#         Current date and time as a formatted string
#
#     Examples:
#         - get_current_time() -> "2024-01-15 10:30:45 UTC"
#         - get_current_time("US/Eastern") -> "2024-01-15 05:30:45 US/Eastern"
#
# 🔧 format_timestamp:
#     Convert a Unix timestamp to a formatted date string.
#
#     Args:
#         timestamp: Unix timestamp (seconds since epoch)
#         format_string: Optional format string (default: "%Y-%m-%d %H:%M:%S")
#
#     Returns:
#         Formatted date string
#
#     Examples:
#         - format_timestamp(1705315200) -> "2024-01-15 08:00:00"
#         - format_timestamp(1705315200, "%B %d, %Y") -> "January 15, 2024"
#
# 🔧 server_info:
#     Get information about the MCP server and available tools.
#
#     Returns:
#         Server information and tool count
#
#
# 🧪 Testing Calculator Tool:
# ==================================================
# calculate('15 + 27') = Result: 42
#
# 🕐 Testing DateTime Tool:
# ==================================================
# get_current_time() = Current time: 2025-11-26 03:13:51 UTC
#
# ✅ MCP Server is working correctly!

# %%
# Stop MCP server
try:
    mcp_proc.terminate()
    mcp_proc.wait(timeout=5)
    print("MCP Server stopped")
except:
    mcp_proc.kill()
    print("MCP Server killed")
# Out:
# MCP Server stopped

# %% [markdown]
# **Expected Output:**
#
# You should see:
# - 8 tools listed from the MCP server
# - Successful calculation result (42)
# - Current timestamp
#
# This confirms the MCP server is working correctly before deployment.

# %% [markdown]
# ## Step 5: Package the MCP Server
#
# Now let's package the MCP server using AgentRun CLI.

# %%
# Package MCP server
# !agentrun pack \
    -f mcp_server \
    --agent-name "mcp-utility-server" \
    --description "MCP server with calculator, file ops, and datetime tools" \
    --language "python" \
    --entrypoint "python main.py" \
    --port 8000 \
    --build-mode "local" \
    --verbose
# Out:
# INFO:agentrun.runtime.pack_runtime:Starting pack process for workspace:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/mcp_
# server
# DEBUG:agentrun.runtime.pack_runtime:Workspace structure validation passed:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/mcp_
# server
# DEBUG:agentrun.runtime.pack_runtime:Creating new metadata
# DEBUG:agentrun.services.metadata_service:Saving metadata to:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/mcp_
# server/agent_metadata.yaml
# DEBUG:agentrun.runtime.pack_runtime:Applied option overrides: {'agent_name':
# 'mcp-utility-server', 'language': 'python', 'entrypoint': 'python main.py',
# 'port': 8000, 'build_mode': 'local'}
# DEBUG:agentrun.runtime.pack_runtime:Found requirements.txt, processing
# dependencies
# DEBUG:agentrun.runtime.pack_runtime:Generated Dockerfile:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/mcp_
# server/Dockerfile
# DEBUG:agentrun.services.metadata_service:Loading metadata from:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/mcp_
# server/agent_metadata.yaml
# DEBUG:agentrun.services.metadata_service:Saving metadata to:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/mcp_
# server/agent_metadata.yaml
# DEBUG:agentrun.services.metadata_service:Updated metadata with:
# {'has_dockerfile': True}
# INFO:agentrun.runtime.pack_runtime:Pack completed successfully: {'agent_name':
# 'mcp-utility-server', 'workspace_path':
# '/Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/mcp
# _server', 'metadata_path':
# '/Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/mcp
# _server/agent_metadata.yaml', 'language': 'python', 'build_mode': 'local',
# 'dockerfile_path':
# '/Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/mcp
# _server/Dockerfile'}
# ⠋ Packaging completed! ✅
# ✅ Successfully packaged agent: mcp-utility-server
# 📁 Workspace:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/mcp_
# server
# 📄 Metadata:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/mcp_
# server/agent_metadata.yaml

# %% [markdown]
# **Expected Output:**
# ```
# ✅ Successfully packaged agent: mcp-utility-server
# 📁 Workspace: /path/to/mcp_server
# 📄 Metadata: /path/to/mcp_server/agent_metadata.yaml
# ```

# %%
# View generated metadata
# !cat mcp_server/agent_metadata.yaml
# Out:
# agent_name: mcp-utility-server
# build_mode: local
# description: MCP server with calculator, file ops, and datetime tools
# entrypoint: python main.py
# language: python
# port: 8000
# requirements_file: requirements.txt

# %% [markdown]
# ## Step 6: Build the MCP Server Image
#
# Build a Docker image for the MCP server.

# %%
# Build MCP server image
# !agentrun build -f mcp_server --verbose
# Out:
# DEBUG:docker.utils.config:Trying paths: ['/Users/ym/.docker/config.json',
# '/Users/ym/.dockercfg']
# DEBUG:docker.utils.config:Found file at path: /Users/ym/.docker/config.json
# DEBUG:docker.auth:Found 'auths' section
# DEBUG:docker.auth:Auth data for https://index.docker.io/v1/ is absent. Client
# might be using a credentials store instead.
# DEBUG:docker.auth:Auth data for https://index.docker.io/v1/access-token is
# absent. Client might be using a credentials store instead.
# DEBUG:docker.auth:Auth data for https://index.docker.io/v1/refresh-token is
# absent. Client might be using a credentials store instead.
# DEBUG:docker.auth:Found 'credsStore' section
# DEBUG:urllib3.connectionpool:http://localhost:None "GET /version HTTP/1.1" 200
# None
# DEBUG:urllib3.connectionpool:http://localhost:None "GET /v1.52/_ping HTTP/1.1"
# 200 None
# INFO:agentrun.services.docker_service:Successfully connected to Docker daemon
# INFO:agentrun.runtime.build_runtime:Starting build process for workspace:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/mcp_
# server
# DEBUG:agentrun.runtime.build_runtime:Build prerequisites validated for:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/mcp_
# server
# DEBUG:agentrun.services.metadata_service:Loading metadata from:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/mcp_
# server/agent_metadata.yaml
# INFO:agentrun.runtime.build_runtime:Starting local Docker build
# DEBUG:urllib3.connectionpool:http://localhost:None "GET /v1.52/_ping HTTP/1.1"
# 200 None
# DEBUG:urllib3.connectionpool:http://localhost:None "GET /v1.52/version HTTP/1.1"
# 200 None
# INFO:agentrun.services.docker_service:Docker version: 29.0.1
# DEBUG:urllib3.connectionpool:http://localhost:None "GET /v1.52/_ping HTTP/1.1"
# 200 None
# DEBUG:urllib3.connectionpool:http://localhost:None "GET /v1.52/version HTTP/1.1"
# 200 None
# INFO:agentrun.services.docker_service:Docker version: 29.0.1
# INFO:agentrun.services.docker_service:Building Docker image:
# mcp-utility-server:latest
# INFO:agentrun.services.docker_service:Dockerfile:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/mcp_
# server/Dockerfile
# INFO:agentrun.services.docker_service:Context:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/mcp_
# server
# DEBUG:docker.api.build:Looking for auth config
# DEBUG:docker.auth:Looking for auth entry for 'https://index.docker.io/v1/'
# DEBUG:docker.auth:Looking for auth entry for
# 'https://index.docker.io/v1/access-token'
# DEBUG:docker.auth:Looking for auth entry for
# 'https://index.docker.io/v1/refresh-token'
# DEBUG:docker.api.build:Sending auth config ('https://index.docker.io/v1/',
# 'https://index.docker.io/v1/access-token',
# 'https://index.docker.io/v1/refresh-token', 'index.docker.io')
# DEBUG:urllib3.connectionpool:http://localhost:None "POST
# /v1.52/build?t=mcp-utility-server%3Alatest&q=False&nocache=False&rm=True&forcerm
# =False&pull=False&dockerfile=Dockerfile HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:http://localhost:None "GET
# /v1.52/images/66607dd7cfeb/json HTTP/1.1" 200 None
# INFO:agentrun.services.docker_service:Docker image built successfully in 37.7s
# DEBUG:urllib3.connectionpool:http://localhost:None "GET
# /v1.52/images/mcp-utility-server:latest/json HTTP/1.1" 200 None
# DEBUG:agentrun.services.docker_service:Build result: {'image_name':
# 'mcp-utility-server:latest', 'image_id': '66607dd7cfeb', 'image_size':
# '404.8MB', 'build_time': '37.7s'}
# DEBUG:agentrun.services.metadata_service:Loading metadata from:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/mcp_
# server/agent_metadata.yaml
# DEBUG:agentrun.services.metadata_service:Saving metadata to:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/mcp_
# server/agent_metadata.yaml
# DEBUG:agentrun.services.metadata_service:Updated metadata with: {'image':
# {'repository_url': 'mcp-utility-server:latest', 'tag': 'latest', 'build_mode':
# 'local', 'build_size': '404.8MB', 'build_time': '37.7s'}}
# DEBUG:agentrun.runtime.build_runtime:Updated metadata with build info:
# {'repository_url': 'mcp-utility-server:latest', 'tag': 'latest', 'build_mode':
# 'local', 'build_size': '404.8MB', 'build_time': '37.7s'}
# INFO:agentrun.runtime.build_runtime:Local build completed: {'image_name':
# 'mcp-utility-server:latest', 'image_tag': 'mcp-utility-server:latest',
# 'image_size': '404.8MB', 'build_time': '37.7s', 'build_mode': 'local'}
# ⠹ Build completed! ✅.
# ✅ Successfully built agent image: mcp-utility-server:latest
# 🏷️  Tag: mcp-utility-server:latest
# 📏 Size: 404.8MB

# %% [markdown]
# **Expected Output:**
# ```
# ✅ Successfully built agent image: mcp-utility-server:latest
# 🏷️  Tag: mcp-utility-server:latest
# 📏 Size: ~XXX MB
# ```

# %%
# Verify Docker image
# !docker images | grep mcp-utility-server
# Out:
# WARNING: This output is designed for human readability. For machine-readable output, please use --format.
# mcp-utility-server:latest                                                                               e2998766c843        424MB             0B

# %% [markdown]
# ## Step 7: Publish MCP Server to Kubernetes
#
# Deploy the MCP server to local Kubernetes cluster.

# %%
# Publish MCP server to Kubernetes
# !agentrun publish \
    -f mcp_server \
    --version "v1.0.0" \
    --image-url "taoruiw/mcp-utility-server:latest" \
    --description "MCP server with utility tools" \
    --verbose \
    --node-port 30000 \
    --use-k8s
# Out:
# DEBUG:docker.utils.config:Trying paths: ['/Users/ym/.docker/config.json',
# '/Users/ym/.dockercfg']
# DEBUG:docker.utils.config:Found file at path: /Users/ym/.docker/config.json
# DEBUG:docker.auth:Found 'auths' section
# DEBUG:docker.auth:Auth data for https://index.docker.io/v1/ is absent. Client
# might be using a credentials store instead.
# DEBUG:docker.auth:Auth data for https://index.docker.io/v1/access-token is
# absent. Client might be using a credentials store instead.
# DEBUG:docker.auth:Auth data for https://index.docker.io/v1/refresh-token is
# absent. Client might be using a credentials store instead.
# DEBUG:docker.auth:Found 'credsStore' section
# DEBUG:urllib3.connectionpool:http://localhost:None "GET /version HTTP/1.1" 200
# None
# DEBUG:urllib3.connectionpool:http://localhost:None "GET /v1.52/_ping HTTP/1.1"
# 200 None
# INFO:agentrun.services.docker_service:Successfully connected to Docker daemon
# INFO:agentrun.services.k8s_provider:Loaded local Kubernetes config
# INFO:agentrun.services.k8s_provider:Kubernetes provider initialized for
# namespace: agentrun
# DEBUG:kubernetes.client.rest:response body:
# {"kind":"Namespace","apiVersion":"v1","metadata":{"name":"agentrun","uid":"40e8b
# dbd-a04c-4884-b7ea-7883ef65df9b","resourceVersion":"16799","creationTimestamp":"
# 2025-11-18T12:02:51Z","labels":{"kubernetes.io/metadata.name":"agentrun"},"manag
# edFields":[{"manager":"OpenAPI-Generator","operation":"Update","apiVersion":"v1"
# ,"time":"2025-11-18T12:02:51Z","fieldsType":"FieldsV1","fieldsV1":{"f:metadata":
# {"f:labels":{".":{},"f:kubernetes.io/metadata.name":{}}}}}]},"spec":{"finalizers
# ":["kubernetes"]},"status":{"phase":"Active"}}
#
# DEBUG:agentrun.services.k8s_provider:Namespace agentrun already exists
# INFO:agentrun.runtime.publish_runtime:Starting publish process for workspace:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/mcp_
# server
# INFO:agentrun.runtime.publish_runtime:Publishing to K8s cluster for workspace:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/mcp_
# server
# DEBUG:agentrun.services.metadata_service:Loading metadata from:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/mcp_
# server/agent_metadata.yaml
# INFO:agentrun.services.k8s_provider:Deploying agent mcp-utility-server to K8s
# cluster
# DEBUG:kubernetes.client.rest:response body:
# {"kind":"Status","apiVersion":"v1","metadata":{},"status":"Failure","message":"d
# eployments.apps \"mcp-utility-server\" not
# found","reason":"NotFound","details":{"name":"mcp-utility-server","group":"apps"
# ,"kind":"deployments"},"code":404}
#
# DEBUG:kubernetes.client.rest:response body:
# {"kind":"Deployment","apiVersion":"apps/v1","metadata":{"name":"mcp-utility-serv
# er","namespace":"agentrun","uid":"4dbc3e7d-5254-40b0-84d4-2d1eb8c9babc","resourc
# eVersion":"77851","generation":1,"creationTimestamp":"2025-11-27T06:52:02Z","man
# agedFields":[{"manager":"OpenAPI-Generator","operation":"Update","apiVersion":"a
# pps/v1","time":"2025-11-27T06:52:02Z","fieldsType":"FieldsV1","fieldsV1":{"f:spe
# c":{"f:progressDeadlineSeconds":{},"f:replicas":{},"f:revisionHistoryLimit":{},"
# f:selector":{},"f:strategy":{"f:rollingUpdate":{".":{},"f:maxSurge":{},"f:maxUna
# vailable":{}},"f:type":{}},"f:template":{"f:metadata":{"f:labels":{".":{},"f:app
# ":{}}},"f:spec":{"f:containers":{"k:{\"name\":\"mcp-utility-server\"}":{".":{},"
# f:args":{},"f:image":{},"f:imagePullPolicy":{},"f:name":{},"f:ports":{".":{},"k:
# {\"containerPort\":8000,\"protocol\":\"TCP\"}":{".":{},"f:containerPort":{},"f:p
# rotocol":{}}},"f:resources":{},"f:terminationMessagePath":{},"f:terminationMessa
# gePolicy":{}}},"f:dnsPolicy":{},"f:restartPolicy":{},"f:schedulerName":{},"f:sec
# urityContext":{},"f:terminationGracePeriodSeconds":{}}}}}}]},"spec":{"replicas":
# 1,"selector":{"matchLabels":{"app":"mcp-utility-server"}},"template":{"metadata"
# :{"labels":{"app":"mcp-utility-server"}},"spec":{"containers":[{"name":"mcp-util
# ity-server","image":"mcp-utility-server:latest","args":["python","main.py"],"por
# ts":[{"containerPort":8000,"protocol":"TCP"}],"resources":{},"terminationMessage
# Path":"/dev/termination-log","terminationMessagePolicy":"File","imagePullPolicy"
# :"IfNotPresent"}],"restartPolicy":"Always","terminationGracePeriodSeconds":30,"d
# nsPolicy":"ClusterFirst","securityContext":{},"schedulerName":"default-scheduler
# "}},"strategy":{"type":"RollingUpdate","rollingUpdate":{"maxUnavailable":"25%","
# maxSurge":"25%"}},"revisionHistoryLimit":10,"progressDeadlineSeconds":600},"stat
# us":{}}
#
# INFO:agentrun.services.k8s_provider:Created new deployment: mcp-utility-server
# DEBUG:kubernetes.client.rest:response body:
# {"kind":"Status","apiVersion":"v1","metadata":{},"status":"Failure","message":"s
# ervices \"mcp-utility-server\" not
# found","reason":"NotFound","details":{"name":"mcp-utility-server","kind":"servic
# es"},"code":404}
#
# DEBUG:kubernetes.client.rest:response body:
# {"kind":"Service","apiVersion":"v1","metadata":{"name":"mcp-utility-server","nam
# espace":"agentrun","uid":"30abb3ff-438b-4e46-bab6-1fc697c94f8e","resourceVersion
# ":"77855","creationTimestamp":"2025-11-27T06:52:02Z","managedFields":[{"manager"
# :"OpenAPI-Generator","operation":"Update","apiVersion":"v1","time":"2025-11-27T0
# 6:52:02Z","fieldsType":"FieldsV1","fieldsV1":{"f:spec":{"f:externalTrafficPolicy
# ":{},"f:internalTrafficPolicy":{},"f:ports":{".":{},"k:{\"port\":8000,\"protocol
# \":\"TCP\"}":{".":{},"f:nodePort":{},"f:port":{},"f:protocol":{},"f:targetPort":
# {}}},"f:selector":{},"f:sessionAffinity":{},"f:type":{}}}}]},"spec":{"ports":[{"
# protocol":"TCP","port":8000,"targetPort":8000,"nodePort":30000}],"selector":{"ap
# p":"mcp-utility-server"},"clusterIP":"10.111.85.177","clusterIPs":["10.111.85.17
# 7"],"type":"NodePort","sessionAffinity":"None","externalTrafficPolicy":"Cluster"
# ,"ipFamilies":["IPv4"],"ipFamilyPolicy":"SingleStack","internalTrafficPolicy":"C
# luster"},"status":{"loadBalancer":{}}}
#
# INFO:agentrun.services.k8s_provider:Created new service: mcp-utility-server
# INFO:agentrun.services.k8s_provider:Waiting for deployment mcp-utility-server to
# be ready...
# DEBUG:kubernetes.client.rest:response body:
# {"kind":"Deployment","apiVersion":"apps/v1","metadata":{"name":"mcp-utility-serv
# er","namespace":"agentrun","uid":"4dbc3e7d-5254-40b0-84d4-2d1eb8c9babc","resourc
# eVersion":"77857","generation":1,"creationTimestamp":"2025-11-27T06:52:02Z","ann
# otations":{"deployment.kubernetes.io/revision":"1"},"managedFields":[{"manager":
# "OpenAPI-Generator","operation":"Update","apiVersion":"apps/v1","time":"2025-11-
# 27T06:52:02Z","fieldsType":"FieldsV1","fieldsV1":{"f:spec":{"f:progressDeadlineS
# econds":{},"f:replicas":{},"f:revisionHistoryLimit":{},"f:selector":{},"f:strate
# gy":{"f:rollingUpdate":{".":{},"f:maxSurge":{},"f:maxUnavailable":{}},"f:type":{
# }},"f:template":{"f:metadata":{"f:labels":{".":{},"f:app":{}}},"f:spec":{"f:cont
# ainers":{"k:{\"name\":\"mcp-utility-server\"}":{".":{},"f:args":{},"f:image":{},
# "f:imagePullPolicy":{},"f:name":{},"f:ports":{".":{},"k:{\"containerPort\":8000,
# \"protocol\":\"TCP\"}":{".":{},"f:containerPort":{},"f:protocol":{}}},"f:resourc
# es":{},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{}}},"f:dnsPol
# icy":{},"f:restartPolicy":{},"f:schedulerName":{},"f:securityContext":{},"f:term
# inationGracePeriodSeconds":{}}}}}},{"manager":"kube-controller-manager","operati
# on":"Update","apiVersion":"apps/v1","time":"2025-11-27T06:52:02Z","fieldsType":"
# FieldsV1","fieldsV1":{"f:metadata":{"f:annotations":{".":{},"f:deployment.kubern
# etes.io/revision":{}}},"f:status":{"f:conditions":{".":{},"k:{\"type\":\"Progres
# sing\"}":{".":{},"f:lastTransitionTime":{},"f:lastUpdateTime":{},"f:message":{},
# "f:reason":{},"f:status":{},"f:type":{}}}}},"subresource":"status"}]},"spec":{"r
# eplicas":1,"selector":{"matchLabels":{"app":"mcp-utility-server"}},"template":{"
# metadata":{"labels":{"app":"mcp-utility-server"}},"spec":{"containers":[{"name":
# "mcp-utility-server","image":"mcp-utility-server:latest","args":["python","main.
# py"],"ports":[{"containerPort":8000,"protocol":"TCP"}],"resources":{},"terminati
# onMessagePath":"/dev/termination-log","terminationMessagePolicy":"File","imagePu
# llPolicy":"IfNotPresent"}],"restartPolicy":"Always","terminationGracePeriodSecon
# ds":30,"dnsPolicy":"ClusterFirst","securityContext":{},"schedulerName":"default-
# scheduler"}},"strategy":{"type":"RollingUpdate","rollingUpdate":{"maxUnavailable
# ":"25%","maxSurge":"25%"}},"revisionHistoryLimit":10,"progressDeadlineSeconds":6
# 00},"status":{"conditions":[{"type":"Progressing","status":"True","lastUpdateTim
# e":"2025-11-27T06:52:02Z","lastTransitionTime":"2025-11-27T06:52:02Z","reason":"
# NewReplicaSetCreated","message":"Created new replica set
# \"mcp-utility-server-8c6578fb6\""}]}}
#
# DEBUG:kubernetes.client.rest:response body:
# {"kind":"Deployment","apiVersion":"apps/v1","metadata":{"name":"mcp-utility-serv
# er","namespace":"agentrun","uid":"4dbc3e7d-5254-40b0-84d4-2d1eb8c9babc","resourc
# eVersion":"77878","generation":1,"creationTimestamp":"2025-11-27T06:52:02Z","ann
# otations":{"deployment.kubernetes.io/revision":"1"},"managedFields":[{"manager":
# "OpenAPI-Generator","operation":"Update","apiVersion":"apps/v1","time":"2025-11-
# 27T06:52:02Z","fieldsType":"FieldsV1","fieldsV1":{"f:spec":{"f:progressDeadlineS
# econds":{},"f:replicas":{},"f:revisionHistoryLimit":{},"f:selector":{},"f:strate
# gy":{"f:rollingUpdate":{".":{},"f:maxSurge":{},"f:maxUnavailable":{}},"f:type":{
# }},"f:template":{"f:metadata":{"f:labels":{".":{},"f:app":{}}},"f:spec":{"f:cont
# ainers":{"k:{\"name\":\"mcp-utility-server\"}":{".":{},"f:args":{},"f:image":{},
# "f:imagePullPolicy":{},"f:name":{},"f:ports":{".":{},"k:{\"containerPort\":8000,
# \"protocol\":\"TCP\"}":{".":{},"f:containerPort":{},"f:protocol":{}}},"f:resourc
# es":{},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{}}},"f:dnsPol
# icy":{},"f:restartPolicy":{},"f:schedulerName":{},"f:securityContext":{},"f:term
# inationGracePeriodSeconds":{}}}}}},{"manager":"kube-controller-manager","operati
# on":"Update","apiVersion":"apps/v1","time":"2025-11-27T06:52:03Z","fieldsType":"
# FieldsV1","fieldsV1":{"f:metadata":{"f:annotations":{".":{},"f:deployment.kubern
# etes.io/revision":{}}},"f:status":{"f:availableReplicas":{},"f:conditions":{".":
# {},"k:{\"type\":\"Available\"}":{".":{},"f:lastTransitionTime":{},"f:lastUpdateT
# ime":{},"f:message":{},"f:reason":{},"f:status":{},"f:type":{}},"k:{\"type\":\"P
# rogressing\"}":{".":{},"f:lastTransitionTime":{},"f:lastUpdateTime":{},"f:messag
# e":{},"f:reason":{},"f:status":{},"f:type":{}}},"f:observedGeneration":{},"f:rea
# dyReplicas":{},"f:replicas":{},"f:updatedReplicas":{}}},"subresource":"status"}]
# },"spec":{"replicas":1,"selector":{"matchLabels":{"app":"mcp-utility-server"}},"
# template":{"metadata":{"labels":{"app":"mcp-utility-server"}},"spec":{"container
# s":[{"name":"mcp-utility-server","image":"mcp-utility-server:latest","args":["py
# thon","main.py"],"ports":[{"containerPort":8000,"protocol":"TCP"}],"resources":{
# },"terminationMessagePath":"/dev/termination-log","terminationMessagePolicy":"Fi
# le","imagePullPolicy":"IfNotPresent"}],"restartPolicy":"Always","terminationGrac
# ePeriodSeconds":30,"dnsPolicy":"ClusterFirst","securityContext":{},"schedulerNam
# e":"default-scheduler"}},"strategy":{"type":"RollingUpdate","rollingUpdate":{"ma
# xUnavailable":"25%","maxSurge":"25%"}},"revisionHistoryLimit":10,"progressDeadli
# neSeconds":600},"status":{"observedGeneration":1,"replicas":1,"updatedReplicas":
# 1,"readyReplicas":1,"availableReplicas":1,"conditions":[{"type":"Available","sta
# tus":"True","lastUpdateTime":"2025-11-27T06:52:03Z","lastTransitionTime":"2025-1
# 1-27T06:52:03Z","reason":"MinimumReplicasAvailable","message":"Deployment has
# minimum
# availability."},{"type":"Progressing","status":"True","lastUpdateTime":"2025-11-
# 27T06:52:03Z","lastTransitionTime":"2025-11-27T06:52:02Z","reason":"NewReplicaSe
# tAvailable","message":"ReplicaSet \"mcp-utility-server-8c6578fb6\" has
# successfully progressed."}]}}
#
# INFO:agentrun.services.k8s_provider:Deployment mcp-utility-server is ready
# INFO:agentrun.services.k8s_provider:Agent deployed successfully:
# {'deployment_name': 'mcp-utility-server', 'service_name': 'mcp-utility-server',
# 'namespace': 'agentrun', 'replicas': 1, 'container_port': 8000, 'node_port':
# 30000, 'service_url': 'http://localhost:30000', 'status': 'deployed'}
# DEBUG:agentrun.services.metadata_service:Loading metadata from:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/mcp_
# server/agent_metadata.yaml
# DEBUG:agentrun.services.metadata_service:Saving metadata to:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/mcp_
# server/agent_metadata.yaml
# DEBUG:agentrun.services.metadata_service:Updated metadata with: {'agent_id':
# 'mcp-utility-server', 'agent_endpoint': 'http://localhost:30000',
# 'k8s_deployment': {'deployment_name': 'mcp-utility-server', 'service_name':
# 'mcp-utility-server', 'namespace': 'agentrun', 'node_port': 30000,
# 'container_port': 8000, 'replicas': 1, 'service_url': 'http://localhost:30000'}}
# INFO:agentrun.runtime.publish_runtime:K8s publish completed: {'agent_name':
# 'mcp-utility-server', 'agent_id': 'mcp-utility-server', 'agent_endpoint':
# 'http://localhost:30000', 'deployment_name': 'mcp-utility-server', 'node_port':
# 30000, 'namespace': 'agentrun'}
# ⠧ Publishing completed! ✅
# ✅ Successfully published agent: mcp-utility-server
# 🆔 Agent ID: mcp-utility-server
# 🌐 Endpoint: http://localhost:30000
# 🔌 NodePort: 30000
# 📦 Namespace: agentrun

# %% [markdown]
# **Expected Output:**
# ```
# ✅ Successfully published agent: mcp-utility-server
# 🌐 Service URL: http://localhost:XXXXX
# 📊 Kubernetes Deployment: mcp-utility-server in namespace agentrun
# ```

# %%
# Check MCP server status
# !agentrun status -f mcp_server --use-k8s --verbose
# Out:
# INFO:agentrun.services.k8s_provider:Loaded local Kubernetes config
# INFO:agentrun.services.k8s_provider:Kubernetes provider initialized for namespace: agentrun
# DEBUG:kubernetes.client.rest:response body: {"kind":"Namespace","apiVersion":"v1","metadata":{"name":"agentrun","uid":"40e8bdbd-a04c-4884-b7ea-7883ef65df9b","resourceVersion":"16799","creationTimestamp":"2025-11-18T12:02:51Z","labels":{"kubernetes.io/metadata.name":"agentrun"},"managedFields":[{"manager":"OpenAPI-Generator","operation":"Update","apiVersion":"v1","time":"2025-11-18T12:02:51Z","fieldsType":"FieldsV1","fieldsV1":{"f:metadata":{"f:labels":{".":{},"f:kubernetes.io/metadata.name":{}}}}}]},"spec":{"finalizers":["kubernetes"]},"status":{"phase":"Active"}}
#
# DEBUG:agentrun.services.k8s_provider:Namespace agentrun already exists
# INFO:agentrun.runtime.status_runtime:Checking agent status for workspace: /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/mcp_server
# DEBUG:agentrun.services.metadata_service:Loading metadata from: /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/mcp_server/agent_metadata.yaml
# INFO:agentrun.runtime.status_runtime:Querying Kubernetes for agent status: mcp-utility-server
# DEBUG:kubernetes.client.rest:response body: {"kind":"Deployment","apiVersion":"apps/v1","metadata":{"name":"mcp-utility-server","namespace":"agentrun","uid":"4dbc3e7d-5254-40b0-84d4-2d1eb8c9babc","resourceVersion":"77878","generation":1,"creationTimestamp":"2025-11-27T06:52:02Z","annotations":{"deployment.kubernetes.io/revision":"1"},"managedFields":[{"manager":"OpenAPI-Generator","operation":"Update","apiVersion":"apps/v1","time":"2025-11-27T06:52:02Z","fieldsType":"FieldsV1","fieldsV1":{"f:spec":{"f:progressDeadlineSeconds":{},"f:replicas":{},"f:revisionHistoryLimit":{},"f:selector":{},"f:strategy":{"f:rollingUpdate":{".":{},"f:maxSurge":{},"f:maxUnavailable":{}},"f:type":{}},"f:template":{"f:metadata":{"f:labels":{".":{},"f:app":{}}},"f:spec":{"f:containers":{"k:{\"name\":\"mcp-utility-server\"}":{".":{},"f:args":{},"f:image":{},"f:imagePullPolicy":{},"f:name":{},"f:ports":{".":{},"k:{\"containerPort\":8000,\"protocol\":\"TCP\"}":{".":{},"f:containerPort":{},"f:protocol":{}}},"f:resources":{},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{}}},"f:dnsPolicy":{},"f:restartPolicy":{},"f:schedulerName":{},"f:securityContext":{},"f:terminationGracePeriodSeconds":{}}}}}},{"manager":"kube-controller-manager","operation":"Update","apiVersion":"apps/v1","time":"2025-11-27T06:52:03Z","fieldsType":"FieldsV1","fieldsV1":{"f:metadata":{"f:annotations":{".":{},"f:deployment.kubernetes.io/revision":{}}},"f:status":{"f:availableReplicas":{},"f:conditions":{".":{},"k:{\"type\":\"Available\"}":{".":{},"f:lastTransitionTime":{},"f:lastUpdateTime":{},"f:message":{},"f:reason":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Progressing\"}":{".":{},"f:lastTransitionTime":{},"f:lastUpdateTime":{},"f:message":{},"f:reason":{},"f:status":{},"f:type":{}}},"f:observedGeneration":{},"f:readyReplicas":{},"f:replicas":{},"f:updatedReplicas":{}}},"subresource":"status"}]},"spec":{"replicas":1,"selector":{"matchLabels":{"app":"mcp-utility-server"}},"template":{"metadata":{"labels":{"app":"mcp-utility-server"}},"spec":{"containers":[{"name":"mcp-utility-server","image":"mcp-utility-server:latest","args":["python","main.py"],"ports":[{"containerPort":8000,"protocol":"TCP"}],"resources":{},"terminationMessagePath":"/dev/termination-log","terminationMessagePolicy":"File","imagePullPolicy":"IfNotPresent"}],"restartPolicy":"Always","terminationGracePeriodSeconds":30,"dnsPolicy":"ClusterFirst","securityContext":{},"schedulerName":"default-scheduler"}},"strategy":{"type":"RollingUpdate","rollingUpdate":{"maxUnavailable":"25%","maxSurge":"25%"}},"revisionHistoryLimit":10,"progressDeadlineSeconds":600},"status":{"observedGeneration":1,"replicas":1,"updatedReplicas":1,"readyReplicas":1,"availableReplicas":1,"conditions":[{"type":"Available","status":"True","lastUpdateTime":"2025-11-27T06:52:03Z","lastTransitionTime":"2025-11-27T06:52:03Z","reason":"MinimumReplicasAvailable","message":"Deployment has minimum availability."},{"type":"Progressing","status":"True","lastUpdateTime":"2025-11-27T06:52:03Z","lastTransitionTime":"2025-11-27T06:52:02Z","reason":"NewReplicaSetAvailable","message":"ReplicaSet \"mcp-utility-server-8c6578fb6\" has successfully progressed."}]}}
#
# DEBUG:kubernetes.client.rest:response body: {"kind":"Service","apiVersion":"v1","metadata":{"name":"mcp-utility-server","namespace":"agentrun","uid":"30abb3ff-438b-4e46-bab6-1fc697c94f8e","resourceVersion":"77855","creationTimestamp":"2025-11-27T06:52:02Z","managedFields":[{"manager":"OpenAPI-Generator","operation":"Update","apiVersion":"v1","time":"2025-11-27T06:52:02Z","fieldsType":"FieldsV1","fieldsV1":{"f:spec":{"f:externalTrafficPolicy":{},"f:internalTrafficPolicy":{},"f:ports":{".":{},"k:{\"port\":8000,\"protocol\":\"TCP\"}":{".":{},"f:nodePort":{},"f:port":{},"f:protocol":{},"f:targetPort":{}}},"f:selector":{},"f:sessionAffinity":{},"f:type":{}}}}]},"spec":{"ports":[{"protocol":"TCP","port":8000,"targetPort":8000,"nodePort":30000}],"selector":{"app":"mcp-utility-server"},"clusterIP":"10.111.85.177","clusterIPs":["10.111.85.177"],"type":"NodePort","sessionAffinity":"None","externalTrafficPolicy":"Cluster","ipFamilies":["IPv4"],"ipFamilyPolicy":"SingleStack","internalTrafficPolicy":"Cluster"},"status":{"loadBalancer":{}}}
#
# DEBUG:kubernetes.client.rest:response body: {"kind":"PodList","apiVersion":"v1","metadata":{"resourceVersion":"77884"},"items":[{"metadata":{"name":"mcp-utility-server-8c6578fb6-n4r6m","generateName":"mcp-utility-server-8c6578fb6-","namespace":"agentrun","uid":"a772f68d-950c-4ad3-93c0-82356f399dea","resourceVersion":"77874","generation":1,"creationTimestamp":"2025-11-27T06:52:02Z","labels":{"app":"mcp-utility-server","pod-template-hash":"8c6578fb6"},"ownerReferences":[{"apiVersion":"apps/v1","kind":"ReplicaSet","name":"mcp-utility-server-8c6578fb6","uid":"4045270b-e5d3-42f6-8c08-2ca8dd5fb438","controller":true,"blockOwnerDeletion":true}],"managedFields":[{"manager":"kube-controller-manager","operation":"Update","apiVersion":"v1","time":"2025-11-27T06:52:02Z","fieldsType":"FieldsV1","fieldsV1":{"f:metadata":{"f:generateName":{},"f:labels":{".":{},"f:app":{},"f:pod-template-hash":{}},"f:ownerReferences":{".":{},"k:{\"uid\":\"4045270b-e5d3-42f6-8c08-2ca8dd5fb438\"}":{}}},"f:spec":{"f:containers":{"k:{\"name\":\"mcp-utility-server\"}":{".":{},"f:args":{},"f:image":{},"f:imagePullPolicy":{},"f:name":{},"f:ports":{".":{},"k:{\"containerPort\":8000,\"protocol\":\"TCP\"}":{".":{},"f:containerPort":{},"f:protocol":{}}},"f:resources":{},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{}}},"f:dnsPolicy":{},"f:enableServiceLinks":{},"f:restartPolicy":{},"f:schedulerName":{},"f:securityContext":{},"f:terminationGracePeriodSeconds":{}}}},{"manager":"kubelet","operation":"Update","apiVersion":"v1","time":"2025-11-27T06:52:03Z","fieldsType":"FieldsV1","fieldsV1":{"f:status":{"f:conditions":{"k:{\"type\":\"ContainersReady\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:observedGeneration":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Initialized\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:observedGeneration":{},"f:status":{},"f:type":{}},"k:{\"type\":\"PodReadyToStartContainers\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:observedGeneration":{},"f:status":{},"f:type":{}},"k:{\"type\":\"PodScheduled\"}":{"f:observedGeneration":{}},"k:{\"type\":\"Ready\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:observedGeneration":{},"f:status":{},"f:type":{}}},"f:containerStatuses":{},"f:hostIP":{},"f:hostIPs":{},"f:observedGeneration":{},"f:phase":{},"f:podIP":{},"f:podIPs":{".":{},"k:{\"ip\":\"10.1.0.52\"}":{".":{},"f:ip":{}}},"f:startTime":{}}},"subresource":"status"}]},"spec":{"volumes":[{"name":"kube-api-access-v5djb","projected":{"sources":[{"serviceAccountToken":{"expirationSeconds":3607,"path":"token"}},{"configMap":{"name":"kube-root-ca.crt","items":[{"key":"ca.crt","path":"ca.crt"}]}},{"downwardAPI":{"items":[{"path":"namespace","fieldRef":{"apiVersion":"v1","fieldPath":"metadata.namespace"}}]}}],"defaultMode":420}}],"containers":[{"name":"mcp-utility-server","image":"mcp-utility-server:latest","args":["python","main.py"],"ports":[{"containerPort":8000,"protocol":"TCP"}],"resources":{},"volumeMounts":[{"name":"kube-api-access-v5djb","readOnly":true,"mountPath":"/var/run/secrets/kubernetes.io/serviceaccount"}],"terminationMessagePath":"/dev/termination-log","terminationMessagePolicy":"File","imagePullPolicy":"IfNotPresent"}],"restartPolicy":"Always","terminationGracePeriodSeconds":30,"dnsPolicy":"ClusterFirst","serviceAccountName":"default","serviceAccount":"default","nodeName":"docker-desktop","securityContext":{},"schedulerName":"default-scheduler","tolerations":[{"key":"node.kubernetes.io/not-ready","operator":"Exists","effect":"NoExecute","tolerationSeconds":300},{"key":"node.kubernetes.io/unreachable","operator":"Exists","effect":"NoExecute","tolerationSeconds":300}],"priority":0,"enableServiceLinks":true,"preemptionPolicy":"PreemptLowerPriority"},"status":{"observedGeneration":1,"phase":"Running","conditions":[{"type":"PodReadyToStartContainers","observedGeneration":1,"status":"True","lastProbeTime":null,"lastTransitionTime":"2025-11-27T06:52:03Z"},{"type":"Initialized" ...
#
# INFO:agentrun.runtime.status_runtime:Kubernetes status retrieved: {'agent_id': 'mcp-utility-server', 'agent_name': 'mcp-utility-server', 'agent_endpoint': 'http://localhost:30000', 'status': 'ready', 'version': 'N/A', 'language': 'python', 'build_mode': 'local', 'k8s_deployment': {'deployment_name': 'mcp-utility-server', 'namespace': 'agentrun', 'replicas': {'desired': 1, 'ready': 1, 'available': 1}, 'service_url': 'http://localhost:30000', 'node_port': 30000, 'pods': [{'name': 'mcp-utility-server-8c6578fb6-n4r6m', 'phase': 'Running', 'ready': True}], 'status': 'ready'}}
#                         Agent Status
# ┏━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Property   ┃ Value                                       ┃
# ┡━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Agent Name │ mcp-utility-server                          │
# │ Agent ID   │ mcp-utility-server                          │
# │ Status     │ ready                                       │
# │ Version    │ N/A                                         │
# │ Language   │ python                                      │
# │ Build Mode │ local                                       │
# │ Endpoint   │ http://localhost:30000                      │
# │ Namespace  │ agentrun                                    │
# │ NodePort   │ 30000                                       │
# │ Replicas   │ 1/1                                         │
# │ Pods       │ mcp-utility-server-8c6578fb6-n4r6m: Running │
# └────────────┴─────────────────────────────────────────────┘

# %%
# Get the MCP server service URL from metadata
import yaml

with open('mcp_server/agent_metadata.yaml', 'r') as f:
    mcp_metadata = yaml.safe_load(f)

mcp_service_url = mcp_metadata.get('k8s_deployment', {}).get('service_url', 'http://localhost:30000')
mcp_server_endpoint = f"{mcp_service_url}/mcp"

print(f"MCP Server Service URL: {mcp_service_url}")
print(f"MCP Server Endpoint: {mcp_server_endpoint}")

# Save for agent configuration
with open('.mcp_server_url.txt', 'w') as f:
    f.write(mcp_server_endpoint)
# Out:
# MCP Server Service URL: http://localhost:30000
# MCP Server Endpoint: http://localhost:30000/mcp

# %% [markdown]
# ## Step 8: Test Deployed MCP Server
#
# Verify the MCP server is working in Kubernetes.

# %%
# Test deployed MCP server
import asyncio
from datetime import timedelta
from mcp import ClientSession
from mcp.client.streamable_http import streamablehttp_client

async def test_deployed_mcp():
    # Read MCP server URL
    with open('.mcp_server_url.txt', 'r') as f:
        mcp_url = f.read().strip()
    
    print(f"Testing MCP server at: {mcp_url}")
    headers = {}
    
    try:
        async with streamablehttp_client(mcp_url, headers, timeout=timedelta(seconds=30), terminate_on_close=False) as (
            read_stream, write_stream, _
        ):
            async with ClientSession(read_stream, write_stream) as session:
                await session.initialize()
                
                # List tools
                tool_result = await session.list_tools()
                print(f"\n✅ MCP Server is running with {len(tool_result.tools)} tools")
                print("\nAvailable tools:")
                for tool in tool_result.tools:
                    print(f"  - {tool.name}")
    except Exception as e:
        print(f"\n❌ Error connecting to MCP server: {e}")
        print("Make sure the MCP server is deployed and accessible")

await test_deployed_mcp()
# Out:
# Testing MCP server at: http://localhost:30000/mcp
#
# ✅ MCP Server is running with 8 tools
#
# Available tools:
#   - calculate
#   - power
#   - write_file
#   - read_file
#   - list_files
#   - get_current_time
#   - format_timestamp
#   - server_info

# %% [markdown]
# ## Step 9: Configure Agent with MCP Server URL
#
# Before packaging the agent, we need to configure it with the MCP server URL.

# %%
# Create agent environment configuration
with open('.mcp_server_url.txt', 'r') as f:
    mcp_url = f.read().strip()

# For Kubernetes deployment, we'll use the service name
# The service name will be mcp-utility-server in the agentrun namespace
k8s_mcp_url = "http://mcp-utility-server.agentrun.svc.cluster.local:8000/mcp"

print(f"Local MCP URL: {mcp_url}")
print(f"Kubernetes MCP URL: {k8s_mcp_url}")
print("\nThe agent will use the Kubernetes service URL when deployed to k8s")
# Out:
# Local MCP URL: http://localhost:30000/mcp
# Kubernetes MCP URL: http://mcp-utility-server.agentrun.svc.cluster.local:30000/mcp
#
# The agent will use the Kubernetes service URL when deployed to k8s

# %% [markdown]
# ## Step 10: Package the LangChain Agent
#
# Now let's package the LangChain agent.

# %%
# Package the agent
# !agentrun pack \
    -f agent \
    --agent-name "langchain-mcp-agent" \
    --description "LangChain agent that uses MCP server tools" \
    --language "python" \
    --entrypoint "python main.py" \
    --port 8080 \
    --build-mode "local" \
    --verbose
# Out:
# INFO:agentrun.runtime.pack_runtime:Starting pack process for workspace:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/agen
# t
# DEBUG:agentrun.runtime.pack_runtime:Workspace structure validation passed:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/agen
# t
# DEBUG:agentrun.services.metadata_service:Loading metadata from:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/agen
# t/agent_metadata.yaml
# DEBUG:agentrun.runtime.pack_runtime:Loaded existing metadata
# DEBUG:agentrun.runtime.pack_runtime:Applied option overrides: {'agent_name':
# 'langchain-mcp-agent', 'language': 'python', 'entrypoint': 'python main.py',
# 'port': 8080, 'build_mode': 'local'}
# DEBUG:agentrun.runtime.pack_runtime:Found requirements.txt, processing
# dependencies
# DEBUG:agentrun.runtime.pack_runtime:Dockerfile already exists, skipping
# generation
# DEBUG:agentrun.services.metadata_service:Loading metadata from:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/agen
# t/agent_metadata.yaml
# DEBUG:agentrun.services.metadata_service:Saving metadata to:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/agen
# t/agent_metadata.yaml
# DEBUG:agentrun.services.metadata_service:Updated metadata with:
# {'has_dockerfile': True}
# INFO:agentrun.runtime.pack_runtime:Pack completed successfully: {'agent_name':
# 'langchain-mcp-agent', 'workspace_path':
# '/Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/age
# nt', 'metadata_path':
# '/Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/age
# nt/agent_metadata.yaml', 'language': 'python', 'build_mode': 'local',
# 'dockerfile_path':
# '/Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/age
# nt/Dockerfile'}
# ⠋ Packaging completed! ✅
# ✅ Successfully packaged agent: langchain-mcp-agent
# 📁 Workspace:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/agen
# t
# 📄 Metadata:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/agen
# t/agent_metadata.yaml

# %% [markdown]
# ## Step 11: Build the Agent Image
#
# Build a Docker image for the LangChain agent.

# %%
# Build agent image
# !agentrun build -f agent --verbose
# Out:
# DEBUG:docker.utils.config:Trying paths: ['/Users/ym/.docker/config.json',
# '/Users/ym/.dockercfg']
# DEBUG:docker.utils.config:Found file at path: /Users/ym/.docker/config.json
# DEBUG:docker.auth:Found 'auths' section
# DEBUG:docker.auth:Auth data for https://index.docker.io/v1/ is absent. Client
# might be using a credentials store instead.
# DEBUG:docker.auth:Auth data for https://index.docker.io/v1/access-token is
# absent. Client might be using a credentials store instead.
# DEBUG:docker.auth:Auth data for https://index.docker.io/v1/refresh-token is
# absent. Client might be using a credentials store instead.
# DEBUG:docker.auth:Found 'credsStore' section
# DEBUG:urllib3.connectionpool:http://localhost:None "GET /version HTTP/1.1" 200
# None
# DEBUG:urllib3.connectionpool:http://localhost:None "GET /v1.52/_ping HTTP/1.1"
# 200 None
# INFO:agentrun.services.docker_service:Successfully connected to Docker daemon
# INFO:agentrun.runtime.build_runtime:Starting build process for workspace:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/agen
# t
# DEBUG:agentrun.runtime.build_runtime:Build prerequisites validated for:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/agen
# t
# DEBUG:agentrun.services.metadata_service:Loading metadata from:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/agen
# t/agent_metadata.yaml
# INFO:agentrun.runtime.build_runtime:Starting local Docker build
# DEBUG:urllib3.connectionpool:http://localhost:None "GET /v1.52/_ping HTTP/1.1"
# 200 None
# DEBUG:urllib3.connectionpool:http://localhost:None "GET /v1.52/version HTTP/1.1"
# 200 None
# INFO:agentrun.services.docker_service:Docker version: 29.0.1
# DEBUG:urllib3.connectionpool:http://localhost:None "GET /v1.52/_ping HTTP/1.1"
# 200 None
# DEBUG:urllib3.connectionpool:http://localhost:None "GET /v1.52/version HTTP/1.1"
# 200 None
# INFO:agentrun.services.docker_service:Docker version: 29.0.1
# INFO:agentrun.services.docker_service:Building Docker image:
# langchain-mcp-agent:latest
# INFO:agentrun.services.docker_service:Dockerfile:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/agen
# t/Dockerfile
# INFO:agentrun.services.docker_service:Context:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/agen
# t
# DEBUG:docker.api.build:Looking for auth config
# DEBUG:docker.auth:Looking for auth entry for 'https://index.docker.io/v1/'
# DEBUG:docker.auth:Looking for auth entry for
# 'https://index.docker.io/v1/access-token'
# DEBUG:docker.auth:Looking for auth entry for
# 'https://index.docker.io/v1/refresh-token'
# DEBUG:docker.api.build:Sending auth config ('https://index.docker.io/v1/',
# 'https://index.docker.io/v1/access-token',
# 'https://index.docker.io/v1/refresh-token', 'index.docker.io')
# DEBUG:urllib3.connectionpool:http://localhost:None "POST
# /v1.52/build?t=langchain-mcp-agent%3Alatest&q=False&nocache=False&rm=True&forcer
# m=False&pull=False&dockerfile=Dockerfile HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:http://localhost:None "GET
# /v1.52/images/3bc5de2a0a8b/json HTTP/1.1" 200 None
# INFO:agentrun.services.docker_service:Docker image built successfully in 52.4s
# DEBUG:urllib3.connectionpool:http://localhost:None "GET
# /v1.52/images/langchain-mcp-agent:latest/json HTTP/1.1" 200 None
# DEBUG:agentrun.services.docker_service:Build result: {'image_name':
# 'langchain-mcp-agent:latest', 'image_id': '3bc5de2a0a8b', 'image_size':
# '503.8MB', 'build_time': '52.4s'}
# DEBUG:agentrun.services.metadata_service:Loading metadata from:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/agen
# t/agent_metadata.yaml
# DEBUG:agentrun.services.metadata_service:Saving metadata to:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/agen
# t/agent_metadata.yaml
# DEBUG:agentrun.services.metadata_service:Updated metadata with: {'image':
# {'repository_url': 'langchain-mcp-agent:latest', 'tag': 'latest', 'build_mode':
# 'local', 'build_size': '503.8MB', 'build_time': '52.4s'}}
# DEBUG:agentrun.runtime.build_runtime:Updated metadata with build info:
# {'repository_url': 'langchain-mcp-agent:latest', 'tag': 'latest', 'build_mode':
# 'local', 'build_size': '503.8MB', 'build_time': '52.4s'}
# INFO:agentrun.runtime.build_runtime:Local build completed: {'image_name':
# 'langchain-mcp-agent:latest', 'image_tag': 'langchain-mcp-agent:latest',
# 'image_size': '503.8MB', 'build_time': '52.4s', 'build_mode': 'local'}
# ⠧ Build completed! ✅.
# ✅ Successfully built agent image: langchain-mcp-agent:latest
# 🏷️  Tag: langchain-mcp-agent:latest
# 📏 Size: 503.8MB

# %%
# Verify Docker image
# !docker images | grep langchain-mcp-agent
# Out:
# WARNING: This output is designed for human readability. For machine-readable output, please use --format.
# langchain-mcp-agent:latest                                                                              e8cc26c18fc7        528MB             0B

# %% [markdown]
# ## Step 12: Publish Agent to Kubernetes
#
# Deploy the LangChain agent to Kubernetes with MCP server URL configured.

# %%
# Publish agent to Kubernetes
# Note: The agent will automatically connect to the MCP server via Kubernetes service discovery
# !agentrun publish \
    -f agent \
    --version "v1.0.0" \
    --image-url "taoruiw/langchain-mcp-agent:latest" \
    --description "LangChain agent with MCP server integration" \
    --verbose \
    --use-k8s
# Out:
# DEBUG:docker.utils.config:Trying paths: ['/Users/ym/.docker/config.json',
# '/Users/ym/.dockercfg']
# DEBUG:docker.utils.config:Found file at path: /Users/ym/.docker/config.json
# DEBUG:docker.auth:Found 'auths' section
# DEBUG:docker.auth:Auth data for https://index.docker.io/v1/ is absent. Client
# might be using a credentials store instead.
# DEBUG:docker.auth:Auth data for https://index.docker.io/v1/access-token is
# absent. Client might be using a credentials store instead.
# DEBUG:docker.auth:Auth data for https://index.docker.io/v1/refresh-token is
# absent. Client might be using a credentials store instead.
# DEBUG:docker.auth:Found 'credsStore' section
# DEBUG:urllib3.connectionpool:http://localhost:None "GET /version HTTP/1.1" 200
# None
# DEBUG:urllib3.connectionpool:http://localhost:None "GET /v1.52/_ping HTTP/1.1"
# 200 None
# INFO:agentrun.services.docker_service:Successfully connected to Docker daemon
# INFO:agentrun.services.k8s_provider:Loaded local Kubernetes config
# INFO:agentrun.services.k8s_provider:Kubernetes provider initialized for
# namespace: agentrun
# DEBUG:kubernetes.client.rest:response body:
# {"kind":"Namespace","apiVersion":"v1","metadata":{"name":"agentrun","uid":"40e8b
# dbd-a04c-4884-b7ea-7883ef65df9b","resourceVersion":"16799","creationTimestamp":"
# 2025-11-18T12:02:51Z","labels":{"kubernetes.io/metadata.name":"agentrun"},"manag
# edFields":[{"manager":"OpenAPI-Generator","operation":"Update","apiVersion":"v1"
# ,"time":"2025-11-18T12:02:51Z","fieldsType":"FieldsV1","fieldsV1":{"f:metadata":
# {"f:labels":{".":{},"f:kubernetes.io/metadata.name":{}}}}}]},"spec":{"finalizers
# ":["kubernetes"]},"status":{"phase":"Active"}}
#
# DEBUG:agentrun.services.k8s_provider:Namespace agentrun already exists
# INFO:agentrun.runtime.publish_runtime:Starting publish process for workspace:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/agen
# t
# INFO:agentrun.runtime.publish_runtime:Publishing to K8s cluster for workspace:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/agen
# t
# DEBUG:agentrun.services.metadata_service:Loading metadata from:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/agen
# t/agent_metadata.yaml
# INFO:agentrun.services.k8s_provider:Deploying agent langchain-mcp-agent to K8s
# cluster
# DEBUG:kubernetes.client.rest:response body:
# {"kind":"Status","apiVersion":"v1","metadata":{},"status":"Failure","message":"d
# eployments.apps \"langchain-mcp-agent\" not
# found","reason":"NotFound","details":{"name":"langchain-mcp-agent","group":"apps
# ","kind":"deployments"},"code":404}
#
# DEBUG:kubernetes.client.rest:response body:
# {"kind":"Deployment","apiVersion":"apps/v1","metadata":{"name":"langchain-mcp-ag
# ent","namespace":"agentrun","uid":"861c6508-0283-4964-9431-197943a5ddfd","resour
# ceVersion":"80446","generation":1,"creationTimestamp":"2025-11-27T07:29:01Z","ma
# nagedFields":[{"manager":"OpenAPI-Generator","operation":"Update","apiVersion":"
# apps/v1","time":"2025-11-27T07:29:01Z","fieldsType":"FieldsV1","fieldsV1":{"f:sp
# ec":{"f:progressDeadlineSeconds":{},"f:replicas":{},"f:revisionHistoryLimit":{},
# "f:selector":{},"f:strategy":{"f:rollingUpdate":{".":{},"f:maxSurge":{},"f:maxUn
# available":{}},"f:type":{}},"f:template":{"f:metadata":{"f:labels":{".":{},"f:ap
# p":{}}},"f:spec":{"f:containers":{"k:{\"name\":\"langchain-mcp-agent\"}":{".":{}
# ,"f:args":{},"f:image":{},"f:imagePullPolicy":{},"f:name":{},"f:ports":{".":{},"
# k:{\"containerPort\":8080,\"protocol\":\"TCP\"}":{".":{},"f:containerPort":{},"f
# :protocol":{}}},"f:resources":{},"f:terminationMessagePath":{},"f:terminationMes
# sagePolicy":{}}},"f:dnsPolicy":{},"f:restartPolicy":{},"f:schedulerName":{},"f:s
# ecurityContext":{},"f:terminationGracePeriodSeconds":{}}}}}}]},"spec":{"replicas
# ":1,"selector":{"matchLabels":{"app":"langchain-mcp-agent"}},"template":{"metada
# ta":{"labels":{"app":"langchain-mcp-agent"}},"spec":{"containers":[{"name":"lang
# chain-mcp-agent","image":"langchain-mcp-agent:latest","args":["python","main.py"
# ],"ports":[{"containerPort":8080,"protocol":"TCP"}],"resources":{},"terminationM
# essagePath":"/dev/termination-log","terminationMessagePolicy":"File","imagePullP
# olicy":"IfNotPresent"}],"restartPolicy":"Always","terminationGracePeriodSeconds"
# :30,"dnsPolicy":"ClusterFirst","securityContext":{},"schedulerName":"default-sch
# eduler"}},"strategy":{"type":"RollingUpdate","rollingUpdate":{"maxUnavailable":"
# 25%","maxSurge":"25%"}},"revisionHistoryLimit":10,"progressDeadlineSeconds":600}
# ,"status":{}}
#
# INFO:agentrun.services.k8s_provider:Created new deployment: langchain-mcp-agent
# DEBUG:kubernetes.client.rest:response body:
# {"kind":"Status","apiVersion":"v1","metadata":{},"status":"Failure","message":"s
# ervices \"langchain-mcp-agent\" not
# found","reason":"NotFound","details":{"name":"langchain-mcp-agent","kind":"servi
# ces"},"code":404}
#
# DEBUG:kubernetes.client.rest:response body:
# {"kind":"Service","apiVersion":"v1","metadata":{"name":"langchain-mcp-agent","na
# mespace":"agentrun","uid":"9a8e2c0e-40a0-449c-8713-3cd59191c96a","resourceVersio
# n":"80449","creationTimestamp":"2025-11-27T07:29:01Z","managedFields":[{"manager
# ":"OpenAPI-Generator","operation":"Update","apiVersion":"v1","time":"2025-11-27T
# 07:29:01Z","fieldsType":"FieldsV1","fieldsV1":{"f:spec":{"f:externalTrafficPolic
# y":{},"f:internalTrafficPolicy":{},"f:ports":{".":{},"k:{\"port\":8080,\"protoco
# l\":\"TCP\"}":{".":{},"f:port":{},"f:protocol":{},"f:targetPort":{}}},"f:selecto
# r":{},"f:sessionAffinity":{},"f:type":{}}}}]},"spec":{"ports":[{"protocol":"TCP"
# ,"port":8080,"targetPort":8080,"nodePort":32754}],"selector":{"app":"langchain-m
# cp-agent"},"clusterIP":"10.96.114.200","clusterIPs":["10.96.114.200"],"type":"No
# dePort","sessionAffinity":"None","externalTrafficPolicy":"Cluster","ipFamilies":
# ["IPv4"],"ipFamilyPolicy":"SingleStack","internalTrafficPolicy":"Cluster"},"stat
# us":{"loadBalancer":{}}}
#
# INFO:agentrun.services.k8s_provider:Created new service: langchain-mcp-agent
# INFO:agentrun.services.k8s_provider:Waiting for deployment langchain-mcp-agent
# to be ready...
# DEBUG:kubernetes.client.rest:response body:
# {"kind":"Deployment","apiVersion":"apps/v1","metadata":{"name":"langchain-mcp-ag
# ent","namespace":"agentrun","uid":"861c6508-0283-4964-9431-197943a5ddfd","resour
# ceVersion":"80446","generation":1,"creationTimestamp":"2025-11-27T07:29:01Z","ma
# nagedFields":[{"manager":"OpenAPI-Generator","operation":"Update","apiVersion":"
# apps/v1","time":"2025-11-27T07:29:01Z","fieldsType":"FieldsV1","fieldsV1":{"f:sp
# ec":{"f:progressDeadlineSeconds":{},"f:replicas":{},"f:revisionHistoryLimit":{},
# "f:selector":{},"f:strategy":{"f:rollingUpdate":{".":{},"f:maxSurge":{},"f:maxUn
# available":{}},"f:type":{}},"f:template":{"f:metadata":{"f:labels":{".":{},"f:ap
# p":{}}},"f:spec":{"f:containers":{"k:{\"name\":\"langchain-mcp-agent\"}":{".":{}
# ,"f:args":{},"f:image":{},"f:imagePullPolicy":{},"f:name":{},"f:ports":{".":{},"
# k:{\"containerPort\":8080,\"protocol\":\"TCP\"}":{".":{},"f:containerPort":{},"f
# :protocol":{}}},"f:resources":{},"f:terminationMessagePath":{},"f:terminationMes
# sagePolicy":{}}},"f:dnsPolicy":{},"f:restartPolicy":{},"f:schedulerName":{},"f:s
# ecurityContext":{},"f:terminationGracePeriodSeconds":{}}}}}}]},"spec":{"replicas
# ":1,"selector":{"matchLabels":{"app":"langchain-mcp-agent"}},"template":{"metada
# ta":{"labels":{"app":"langchain-mcp-agent"}},"spec":{"containers":[{"name":"lang
# chain-mcp-agent","image":"langchain-mcp-agent:latest","args":["python","main.py"
# ],"ports":[{"containerPort":8080,"protocol":"TCP"}],"resources":{},"terminationM
# essagePath":"/dev/termination-log","terminationMessagePolicy":"File","imagePullP
# olicy":"IfNotPresent"}],"restartPolicy":"Always","terminationGracePeriodSeconds"
# :30,"dnsPolicy":"ClusterFirst","securityContext":{},"schedulerName":"default-sch
# eduler"}},"strategy":{"type":"RollingUpdate","rollingUpdate":{"maxUnavailable":"
# 25%","maxSurge":"25%"}},"revisionHistoryLimit":10,"progressDeadlineSeconds":600}
# ,"status":{}}
#
# DEBUG:kubernetes.client.rest:response body:
# {"kind":"Deployment","apiVersion":"apps/v1","metadata":{"name":"langchain-mcp-ag
# ent","namespace":"agentrun","uid":"861c6508-0283-4964-9431-197943a5ddfd","resour
# ceVersion":"80474","generation":1,"creationTimestamp":"2025-11-27T07:29:01Z","an
# notations":{"deployment.kubernetes.io/revision":"1"},"managedFields":[{"manager"
# :"OpenAPI-Generator","operation":"Update","apiVersion":"apps/v1","time":"2025-11
# -27T07:29:01Z","fieldsType":"FieldsV1","fieldsV1":{"f:spec":{"f:progressDeadline
# Seconds":{},"f:replicas":{},"f:revisionHistoryLimit":{},"f:selector":{},"f:strat
# egy":{"f:rollingUpdate":{".":{},"f:maxSurge":{},"f:maxUnavailable":{}},"f:type":
# {}},"f:template":{"f:metadata":{"f:labels":{".":{},"f:app":{}}},"f:spec":{"f:con
# tainers":{"k:{\"name\":\"langchain-mcp-agent\"}":{".":{},"f:args":{},"f:image":{
# },"f:imagePullPolicy":{},"f:name":{},"f:ports":{".":{},"k:{\"containerPort\":808
# 0,\"protocol\":\"TCP\"}":{".":{},"f:containerPort":{},"f:protocol":{}}},"f:resou
# rces":{},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{}}},"f:dnsP
# olicy":{},"f:restartPolicy":{},"f:schedulerName":{},"f:securityContext":{},"f:te
# rminationGracePeriodSeconds":{}}}}}},{"manager":"kube-controller-manager","opera
# tion":"Update","apiVersion":"apps/v1","time":"2025-11-27T07:29:02Z","fieldsType"
# :"FieldsV1","fieldsV1":{"f:metadata":{"f:annotations":{".":{},"f:deployment.kube
# rnetes.io/revision":{}}},"f:status":{"f:availableReplicas":{},"f:conditions":{".
# ":{},"k:{\"type\":\"Available\"}":{".":{},"f:lastTransitionTime":{},"f:lastUpdat
# eTime":{},"f:message":{},"f:reason":{},"f:status":{},"f:type":{}},"k:{\"type\":\
# "Progressing\"}":{".":{},"f:lastTransitionTime":{},"f:lastUpdateTime":{},"f:mess
# age":{},"f:reason":{},"f:status":{},"f:type":{}}},"f:observedGeneration":{},"f:r
# eadyReplicas":{},"f:replicas":{},"f:updatedReplicas":{}}},"subresource":"status"
# }]},"spec":{"replicas":1,"selector":{"matchLabels":{"app":"langchain-mcp-agent"}
# },"template":{"metadata":{"labels":{"app":"langchain-mcp-agent"}},"spec":{"conta
# iners":[{"name":"langchain-mcp-agent","image":"langchain-mcp-agent:latest","args
# ":["python","main.py"],"ports":[{"containerPort":8080,"protocol":"TCP"}],"resour
# ces":{},"terminationMessagePath":"/dev/termination-log","terminationMessagePolic
# y":"File","imagePullPolicy":"IfNotPresent"}],"restartPolicy":"Always","terminati
# onGracePeriodSeconds":30,"dnsPolicy":"ClusterFirst","securityContext":{},"schedu
# lerName":"default-scheduler"}},"strategy":{"type":"RollingUpdate","rollingUpdate
# ":{"maxUnavailable":"25%","maxSurge":"25%"}},"revisionHistoryLimit":10,"progress
# DeadlineSeconds":600},"status":{"observedGeneration":1,"replicas":1,"updatedRepl
# icas":1,"readyReplicas":1,"availableReplicas":1,"conditions":[{"type":"Available
# ","status":"True","lastUpdateTime":"2025-11-27T07:29:02Z","lastTransitionTime":"
# 2025-11-27T07:29:02Z","reason":"MinimumReplicasAvailable","message":"Deployment
# has minimum
# availability."},{"type":"Progressing","status":"True","lastUpdateTime":"2025-11-
# 27T07:29:02Z","lastTransitionTime":"2025-11-27T07:29:01Z","reason":"NewReplicaSe
# tAvailable","message":"ReplicaSet \"langchain-mcp-agent-775c8657bc\" has
# successfully progressed."}]}}
#
# INFO:agentrun.services.k8s_provider:Deployment langchain-mcp-agent is ready
# INFO:agentrun.services.k8s_provider:Agent deployed successfully:
# {'deployment_name': 'langchain-mcp-agent', 'service_name':
# 'langchain-mcp-agent', 'namespace': 'agentrun', 'replicas': 1, 'container_port':
# 8080, 'node_port': 32754, 'service_url': 'http://localhost:32754', 'status':
# 'deployed'}
# DEBUG:agentrun.services.metadata_service:Loading metadata from:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/agen
# t/agent_metadata.yaml
# DEBUG:agentrun.services.metadata_service:Saving metadata to:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/agen
# t/agent_metadata.yaml
# DEBUG:agentrun.services.metadata_service:Updated metadata with: {'agent_id':
# 'langchain-mcp-agent', 'agent_endpoint': 'http://localhost:32754',
# 'k8s_deployment': {'deployment_name': 'langchain-mcp-agent', 'service_name':
# 'langchain-mcp-agent', 'namespace': 'agentrun', 'node_port': 32754,
# 'container_port': 8080, 'replicas': 1, 'service_url': 'http://localhost:32754'}}
# INFO:agentrun.runtime.publish_runtime:K8s publish completed: {'agent_name':
# 'langchain-mcp-agent', 'agent_id': 'langchain-mcp-agent', 'agent_endpoint':
# 'http://localhost:32754', 'deployment_name': 'langchain-mcp-agent', 'node_port':
# 32754, 'namespace': 'agentrun'}
# ⠦ Publishing completed! ✅
# ✅ Successfully published agent: langchain-mcp-agent
# 🆔 Agent ID: langchain-mcp-agent
# 🌐 Endpoint: http://localhost:32754
# 🔌 NodePort: 32754
# 📦 Namespace: agentrun

# %% [markdown]
# **Note**: In a production environment, you would set environment variables in the Kubernetes deployment to configure the MCP_SERVER_URL. For this tutorial, the agent defaults to connecting to the MCP server service within the cluster.

# %%
# Check agent status
# !agentrun status -f agent --use-k8s --verbose
# Out:
# INFO:agentrun.services.k8s_provider:Loaded local Kubernetes config
# INFO:agentrun.services.k8s_provider:Kubernetes provider initialized for namespace: agentrun
# DEBUG:kubernetes.client.rest:response body: {"kind":"Namespace","apiVersion":"v1","metadata":{"name":"agentrun","uid":"40e8bdbd-a04c-4884-b7ea-7883ef65df9b","resourceVersion":"16799","creationTimestamp":"2025-11-18T12:02:51Z","labels":{"kubernetes.io/metadata.name":"agentrun"},"managedFields":[{"manager":"OpenAPI-Generator","operation":"Update","apiVersion":"v1","time":"2025-11-18T12:02:51Z","fieldsType":"FieldsV1","fieldsV1":{"f:metadata":{"f:labels":{".":{},"f:kubernetes.io/metadata.name":{}}}}}]},"spec":{"finalizers":["kubernetes"]},"status":{"phase":"Active"}}
#
# DEBUG:agentrun.services.k8s_provider:Namespace agentrun already exists
# INFO:agentrun.runtime.status_runtime:Checking agent status for workspace: /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/agent
# DEBUG:agentrun.services.metadata_service:Loading metadata from: /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/agent/agent_metadata.yaml
# INFO:agentrun.runtime.status_runtime:Querying Kubernetes for agent status: langchain-mcp-agent
# DEBUG:kubernetes.client.rest:response body: {"kind":"Deployment","apiVersion":"apps/v1","metadata":{"name":"langchain-mcp-agent","namespace":"agentrun","uid":"861c6508-0283-4964-9431-197943a5ddfd","resourceVersion":"80474","generation":1,"creationTimestamp":"2025-11-27T07:29:01Z","annotations":{"deployment.kubernetes.io/revision":"1"},"managedFields":[{"manager":"OpenAPI-Generator","operation":"Update","apiVersion":"apps/v1","time":"2025-11-27T07:29:01Z","fieldsType":"FieldsV1","fieldsV1":{"f:spec":{"f:progressDeadlineSeconds":{},"f:replicas":{},"f:revisionHistoryLimit":{},"f:selector":{},"f:strategy":{"f:rollingUpdate":{".":{},"f:maxSurge":{},"f:maxUnavailable":{}},"f:type":{}},"f:template":{"f:metadata":{"f:labels":{".":{},"f:app":{}}},"f:spec":{"f:containers":{"k:{\"name\":\"langchain-mcp-agent\"}":{".":{},"f:args":{},"f:image":{},"f:imagePullPolicy":{},"f:name":{},"f:ports":{".":{},"k:{\"containerPort\":8080,\"protocol\":\"TCP\"}":{".":{},"f:containerPort":{},"f:protocol":{}}},"f:resources":{},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{}}},"f:dnsPolicy":{},"f:restartPolicy":{},"f:schedulerName":{},"f:securityContext":{},"f:terminationGracePeriodSeconds":{}}}}}},{"manager":"kube-controller-manager","operation":"Update","apiVersion":"apps/v1","time":"2025-11-27T07:29:02Z","fieldsType":"FieldsV1","fieldsV1":{"f:metadata":{"f:annotations":{".":{},"f:deployment.kubernetes.io/revision":{}}},"f:status":{"f:availableReplicas":{},"f:conditions":{".":{},"k:{\"type\":\"Available\"}":{".":{},"f:lastTransitionTime":{},"f:lastUpdateTime":{},"f:message":{},"f:reason":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Progressing\"}":{".":{},"f:lastTransitionTime":{},"f:lastUpdateTime":{},"f:message":{},"f:reason":{},"f:status":{},"f:type":{}}},"f:observedGeneration":{},"f:readyReplicas":{},"f:replicas":{},"f:updatedReplicas":{}}},"subresource":"status"}]},"spec":{"replicas":1,"selector":{"matchLabels":{"app":"langchain-mcp-agent"}},"template":{"metadata":{"labels":{"app":"langchain-mcp-agent"}},"spec":{"containers":[{"name":"langchain-mcp-agent","image":"langchain-mcp-agent:latest","args":["python","main.py"],"ports":[{"containerPort":8080,"protocol":"TCP"}],"resources":{},"terminationMessagePath":"/dev/termination-log","terminationMessagePolicy":"File","imagePullPolicy":"IfNotPresent"}],"restartPolicy":"Always","terminationGracePeriodSeconds":30,"dnsPolicy":"ClusterFirst","securityContext":{},"schedulerName":"default-scheduler"}},"strategy":{"type":"RollingUpdate","rollingUpdate":{"maxUnavailable":"25%","maxSurge":"25%"}},"revisionHistoryLimit":10,"progressDeadlineSeconds":600},"status":{"observedGeneration":1,"replicas":1,"updatedReplicas":1,"readyReplicas":1,"availableReplicas":1,"conditions":[{"type":"Available","status":"True","lastUpdateTime":"2025-11-27T07:29:02Z","lastTransitionTime":"2025-11-27T07:29:02Z","reason":"MinimumReplicasAvailable","message":"Deployment has minimum availability."},{"type":"Progressing","status":"True","lastUpdateTime":"2025-11-27T07:29:02Z","lastTransitionTime":"2025-11-27T07:29:01Z","reason":"NewReplicaSetAvailable","message":"ReplicaSet \"langchain-mcp-agent-775c8657bc\" has successfully progressed."}]}}
#
# DEBUG:kubernetes.client.rest:response body: {"kind":"Service","apiVersion":"v1","metadata":{"name":"langchain-mcp-agent","namespace":"agentrun","uid":"9a8e2c0e-40a0-449c-8713-3cd59191c96a","resourceVersion":"80449","creationTimestamp":"2025-11-27T07:29:01Z","managedFields":[{"manager":"OpenAPI-Generator","operation":"Update","apiVersion":"v1","time":"2025-11-27T07:29:01Z","fieldsType":"FieldsV1","fieldsV1":{"f:spec":{"f:externalTrafficPolicy":{},"f:internalTrafficPolicy":{},"f:ports":{".":{},"k:{\"port\":8080,\"protocol\":\"TCP\"}":{".":{},"f:port":{},"f:protocol":{},"f:targetPort":{}}},"f:selector":{},"f:sessionAffinity":{},"f:type":{}}}}]},"spec":{"ports":[{"protocol":"TCP","port":8080,"targetPort":8080,"nodePort":32754}],"selector":{"app":"langchain-mcp-agent"},"clusterIP":"10.96.114.200","clusterIPs":["10.96.114.200"],"type":"NodePort","sessionAffinity":"None","externalTrafficPolicy":"Cluster","ipFamilies":["IPv4"],"ipFamilyPolicy":"SingleStack","internalTrafficPolicy":"Cluster"},"status":{"loadBalancer":{}}}
#
# DEBUG:kubernetes.client.rest:response body: {"kind":"PodList","apiVersion":"v1","metadata":{"resourceVersion":"80491"},"items":[{"metadata":{"name":"langchain-mcp-agent-775c8657bc-lmwnx","generateName":"langchain-mcp-agent-775c8657bc-","namespace":"agentrun","uid":"636e3bc1-dde5-4c2f-83de-b9714eb18bec","resourceVersion":"80470","generation":1,"creationTimestamp":"2025-11-27T07:29:01Z","labels":{"app":"langchain-mcp-agent","pod-template-hash":"775c8657bc"},"ownerReferences":[{"apiVersion":"apps/v1","kind":"ReplicaSet","name":"langchain-mcp-agent-775c8657bc","uid":"02e0d405-e27c-4739-9890-3b65392ecfe6","controller":true,"blockOwnerDeletion":true}],"managedFields":[{"manager":"kube-controller-manager","operation":"Update","apiVersion":"v1","time":"2025-11-27T07:29:01Z","fieldsType":"FieldsV1","fieldsV1":{"f:metadata":{"f:generateName":{},"f:labels":{".":{},"f:app":{},"f:pod-template-hash":{}},"f:ownerReferences":{".":{},"k:{\"uid\":\"02e0d405-e27c-4739-9890-3b65392ecfe6\"}":{}}},"f:spec":{"f:containers":{"k:{\"name\":\"langchain-mcp-agent\"}":{".":{},"f:args":{},"f:image":{},"f:imagePullPolicy":{},"f:name":{},"f:ports":{".":{},"k:{\"containerPort\":8080,\"protocol\":\"TCP\"}":{".":{},"f:containerPort":{},"f:protocol":{}}},"f:resources":{},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{}}},"f:dnsPolicy":{},"f:enableServiceLinks":{},"f:restartPolicy":{},"f:schedulerName":{},"f:securityContext":{},"f:terminationGracePeriodSeconds":{}}}},{"manager":"kubelet","operation":"Update","apiVersion":"v1","time":"2025-11-27T07:29:02Z","fieldsType":"FieldsV1","fieldsV1":{"f:status":{"f:conditions":{"k:{\"type\":\"ContainersReady\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:observedGeneration":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Initialized\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:observedGeneration":{},"f:status":{},"f:type":{}},"k:{\"type\":\"PodReadyToStartContainers\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:observedGeneration":{},"f:status":{},"f:type":{}},"k:{\"type\":\"PodScheduled\"}":{"f:observedGeneration":{}},"k:{\"type\":\"Ready\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:observedGeneration":{},"f:status":{},"f:type":{}}},"f:containerStatuses":{},"f:hostIP":{},"f:hostIPs":{},"f:observedGeneration":{},"f:phase":{},"f:podIP":{},"f:podIPs":{".":{},"k:{\"ip\":\"10.1.0.55\"}":{".":{},"f:ip":{}}},"f:startTime":{}}},"subresource":"status"}]},"spec":{"volumes":[{"name":"kube-api-access-8lhlt","projected":{"sources":[{"serviceAccountToken":{"expirationSeconds":3607,"path":"token"}},{"configMap":{"name":"kube-root-ca.crt","items":[{"key":"ca.crt","path":"ca.crt"}]}},{"downwardAPI":{"items":[{"path":"namespace","fieldRef":{"apiVersion":"v1","fieldPath":"metadata.namespace"}}]}}],"defaultMode":420}}],"containers":[{"name":"langchain-mcp-agent","image":"langchain-mcp-agent:latest","args":["python","main.py"],"ports":[{"containerPort":8080,"protocol":"TCP"}],"resources":{},"volumeMounts":[{"name":"kube-api-access-8lhlt","readOnly":true,"mountPath":"/var/run/secrets/kubernetes.io/serviceaccount"}],"terminationMessagePath":"/dev/termination-log","terminationMessagePolicy":"File","imagePullPolicy":"IfNotPresent"}],"restartPolicy":"Always","terminationGracePeriodSeconds":30,"dnsPolicy":"ClusterFirst","serviceAccountName":"default","serviceAccount":"default","nodeName":"docker-desktop","securityContext":{},"schedulerName":"default-scheduler","tolerations":[{"key":"node.kubernetes.io/not-ready","operator":"Exists","effect":"NoExecute","tolerationSeconds":300},{"key":"node.kubernetes.io/unreachable","operator":"Exists","effect":"NoExecute","tolerationSeconds":300}],"priority":0,"enableServiceLinks":true,"preemptionPolicy":"PreemptLowerPriority"},"status":{"observedGeneration":1,"phase":"Running","conditions":[{"type":"PodReadyToStartContainers","observedGeneration":1,"status":"True","lastProbeTime":null,"lastTransitionTime":"2025-11-27T07:29:02Z"},{"type":"I ...
#
# INFO:agentrun.runtime.status_runtime:Kubernetes status retrieved: {'agent_id': 'langchain-mcp-agent', 'agent_name': 'langchain-mcp-agent', 'agent_endpoint': 'http://localhost:32754', 'status': 'ready', 'version': 'N/A', 'language': 'python', 'build_mode': 'local', 'k8s_deployment': {'deployment_name': 'langchain-mcp-agent', 'namespace': 'agentrun', 'replicas': {'desired': 1, 'ready': 1, 'available': 1}, 'service_url': 'http://localhost:32754', 'node_port': 32754, 'pods': [{'name': 'langchain-mcp-agent-775c8657bc-lmwnx', 'phase': 'Running', 'ready': True}], 'status': 'ready'}}
#                          Agent Status
# ┏━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Property   ┃ Value                                         ┃
# ┡━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Agent Name │ langchain-mcp-agent                           │
# │ Agent ID   │ langchain-mcp-agent                           │
# │ Status     │ ready                                         │
# │ Version    │ N/A                                           │
# │ Language   │ python                                        │
# │ Build Mode │ local                                         │
# │ Endpoint   │ http://localhost:32754                        │
# │ Namespace  │ agentrun                                      │
# │ NodePort   │ 32754                                         │
# │ Replicas   │ 1/1                                           │
# │ Pods       │ langchain-mcp-agent-775c8657bc-lmwnx: Running │
# └────────────┴───────────────────────────────────────────────┘

# %% [markdown]
# ## Step 13: Test the Integrated System
#
# Now let's test the complete system: agent communicating with MCP server.

# %%
# Test agent health
# !agentrun invoke \
    -f agent \
    --payload '{"prompt": "health check"}' \
    --verbose \
    --use-k8s
# Out:
# INFO:agentrun.services.k8s_provider:Loaded local Kubernetes config
# INFO:agentrun.services.k8s_provider:Kubernetes provider initialized for
# namespace: agentrun
# DEBUG:kubernetes.client.rest:response body:
# {"kind":"Namespace","apiVersion":"v1","metadata":{"name":"agentrun","uid":"40e8b
# dbd-a04c-4884-b7ea-7883ef65df9b","resourceVersion":"16799","creationTimestamp":"
# 2025-11-18T12:02:51Z","labels":{"kubernetes.io/metadata.name":"agentrun"},"manag
# edFields":[{"manager":"OpenAPI-Generator","operation":"Update","apiVersion":"v1"
# ,"time":"2025-11-18T12:02:51Z","fieldsType":"FieldsV1","fieldsV1":{"f:metadata":
# {"f:labels":{".":{},"f:kubernetes.io/metadata.name":{}}}}}]},"spec":{"finalizers
# ":["kubernetes"]},"status":{"phase":"Active"}}
#
# DEBUG:agentrun.services.k8s_provider:Namespace agentrun already exists
# INFO:agentrun.runtime.invoke_runtime:Starting agent invocation for workspace:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/agen
# t
# DEBUG:agentrun.services.metadata_service:Loading metadata from:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/agen
# t/agent_metadata.yaml
# DEBUG:agentrun.runtime.invoke_runtime:Invocation prerequisites validated:
# agent_id=langchain-mcp-agent
# DEBUG:asyncio:Using selector: KqueueSelector
# INFO:agentrun.runtime.invoke_runtime:Invoking agent langchain-mcp-agent at
# http://localhost:32754
# INFO:agentrun.runtime.invoke_runtime:Making HTTP POST request to
# http://localhost:32754
# DEBUG:httpcore.connection:connect_tcp.started host='127.0.0.1' port=7897
# local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete
# return_value=<httpcore._backends.anyio.AnyIOStream object at 0x108a77090>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request
# [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete
# return_value=(b'HTTP/1.1', 200, b'OK', [(b'Connection', b'close'),
# (b'Content-Length', b'370'), (b'Content-Type', b'application/json'), (b'Date',
# b'Thu, 27 Nov 2025 07:29:55 GMT'), (b'Server', b'uvicorn')])
# INFO:httpx:HTTP Request: POST http://localhost:32754 "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# INFO:agentrun.runtime.invoke_runtime:Agent invoked successfully:
# langchain-mcp-agent
# ⠙ Invocation completed! ✅
# ✅ Successfully invoked agent
# 📤 Response: {'response': "[Mock Mode] Received prompt: 'health check'. In
# production, this would use the LangChain agent with MCP tools. Available tools
# from MCP server: calculate, power, write_file, read_file, list_files,
# get_current_time, format_timestamp, server_info. Set OPENAI_API_KEY environment
# variable for real agent responses.", 'success': True, 'error': None,
# 'tools_used': []}

# %%
# Test calculator tool through agent
# !agentrun invoke \
    -f agent \
    --payload '{"prompt": "Calculate 25 multiplied by 4"}' \
    --verbose \
    --use-k8s
# Out:
# INFO:agentrun.services.k8s_provider:Loaded local Kubernetes config
# INFO:agentrun.services.k8s_provider:Kubernetes provider initialized for
# namespace: agentrun
# DEBUG:kubernetes.client.rest:response body:
# {"kind":"Namespace","apiVersion":"v1","metadata":{"name":"agentrun","uid":"40e8b
# dbd-a04c-4884-b7ea-7883ef65df9b","resourceVersion":"16799","creationTimestamp":"
# 2025-11-18T12:02:51Z","labels":{"kubernetes.io/metadata.name":"agentrun"},"manag
# edFields":[{"manager":"OpenAPI-Generator","operation":"Update","apiVersion":"v1"
# ,"time":"2025-11-18T12:02:51Z","fieldsType":"FieldsV1","fieldsV1":{"f:metadata":
# {"f:labels":{".":{},"f:kubernetes.io/metadata.name":{}}}}}]},"spec":{"finalizers
# ":["kubernetes"]},"status":{"phase":"Active"}}
#
# DEBUG:agentrun.services.k8s_provider:Namespace agentrun already exists
# INFO:agentrun.runtime.invoke_runtime:Starting agent invocation for workspace:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/agen
# t
# DEBUG:agentrun.services.metadata_service:Loading metadata from:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/agen
# t/agent_metadata.yaml
# DEBUG:agentrun.runtime.invoke_runtime:Invocation prerequisites validated:
# agent_id=langchain-mcp-agent
# DEBUG:asyncio:Using selector: KqueueSelector
# INFO:agentrun.runtime.invoke_runtime:Invoking agent langchain-mcp-agent at
# http://localhost:32754
# INFO:agentrun.runtime.invoke_runtime:Making HTTP POST request to
# http://localhost:32754
# DEBUG:httpcore.connection:connect_tcp.started host='127.0.0.1' port=7897
# local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete
# return_value=<httpcore._backends.anyio.AnyIOStream object at 0x110a3e750>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request
# [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete
# return_value=(b'HTTP/1.1', 200, b'OK', [(b'Connection', b'close'),
# (b'Content-Length', b'386'), (b'Content-Type', b'application/json'), (b'Date',
# b'Thu, 27 Nov 2025 07:30:25 GMT'), (b'Server', b'uvicorn')])
# INFO:httpx:HTTP Request: POST http://localhost:32754 "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# INFO:agentrun.runtime.invoke_runtime:Agent invoked successfully:
# langchain-mcp-agent
# ⠙ Invocation completed! ✅
# ✅ Successfully invoked agent
# 📤 Response: {'response': "[Mock Mode] Received prompt: 'Calculate 25 multiplied
# by 4'. In production, this would use the LangChain agent with MCP tools.
# Available tools from MCP server: calculate, power, write_file, read_file,
# list_files, get_current_time, format_timestamp, server_info. Set OPENAI_API_KEY
# environment variable for real agent responses.", 'success': True, 'error': None,
# 'tools_used': []}

# %% [markdown]
# **Expected Output (Mock Mode):**
# ```
# ✅ Successfully invoked agent
# 📤 Response: [Mock Mode] Received prompt: 'Calculate 25 multiplied by 4'.
# Available tools from MCP server: calculate, power, write_file, read_file,
# list_files, get_current_time, format_timestamp, server_info.
# Set OPENAI_API_KEY environment variable for real agent responses.
# ```
#
# **Expected Output (Production Mode with OpenAI API key):**
# ```
# ✅ Successfully invoked agent
# 📤 Response: The result of 25 multiplied by 4 is 100.
# ```

# %%
# Test datetime tool
# !agentrun invoke \
    -f agent \
    --payload '{"prompt": "What is the current time?"}' \
    --verbose \
    --use-k8s
# Out:
# INFO:agentrun.services.k8s_provider:Loaded local Kubernetes config
# INFO:agentrun.services.k8s_provider:Kubernetes provider initialized for
# namespace: agentrun
# DEBUG:kubernetes.client.rest:response body:
# {"kind":"Namespace","apiVersion":"v1","metadata":{"name":"agentrun","uid":"40e8b
# dbd-a04c-4884-b7ea-7883ef65df9b","resourceVersion":"16799","creationTimestamp":"
# 2025-11-18T12:02:51Z","labels":{"kubernetes.io/metadata.name":"agentrun"},"manag
# edFields":[{"manager":"OpenAPI-Generator","operation":"Update","apiVersion":"v1"
# ,"time":"2025-11-18T12:02:51Z","fieldsType":"FieldsV1","fieldsV1":{"f:metadata":
# {"f:labels":{".":{},"f:kubernetes.io/metadata.name":{}}}}}]},"spec":{"finalizers
# ":["kubernetes"]},"status":{"phase":"Active"}}
#
# DEBUG:agentrun.services.k8s_provider:Namespace agentrun already exists
# INFO:agentrun.runtime.invoke_runtime:Starting agent invocation for workspace:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/agen
# t
# DEBUG:agentrun.services.metadata_service:Loading metadata from:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/agen
# t/agent_metadata.yaml
# DEBUG:agentrun.runtime.invoke_runtime:Invocation prerequisites validated:
# agent_id=langchain-mcp-agent
# DEBUG:asyncio:Using selector: KqueueSelector
# INFO:agentrun.runtime.invoke_runtime:Invoking agent langchain-mcp-agent at
# http://localhost:32754
# INFO:agentrun.runtime.invoke_runtime:Making HTTP POST request to
# http://localhost:32754
# DEBUG:httpcore.connection:connect_tcp.started host='127.0.0.1' port=7897
# local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete
# return_value=<httpcore._backends.anyio.AnyIOStream object at 0x105145b90>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request
# [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete
# return_value=(b'HTTP/1.1', 200, b'OK', [(b'Connection', b'close'),
# (b'Content-Length', b'383'), (b'Content-Type', b'application/json'), (b'Date',
# b'Thu, 27 Nov 2025 07:32:28 GMT'), (b'Server', b'uvicorn')])
# INFO:httpx:HTTP Request: POST http://localhost:32754 "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# INFO:agentrun.runtime.invoke_runtime:Agent invoked successfully:
# langchain-mcp-agent
# ⠹ Invocation completed! ✅
# ✅ Successfully invoked agent
# 📤 Response: {'response': "[Mock Mode] Received prompt: 'What is the current
# time?'. In production, this would use the LangChain agent with MCP tools.
# Available tools from MCP server: calculate, power, write_file, read_file,
# list_files, get_current_time, format_timestamp, server_info. Set OPENAI_API_KEY
# environment variable for real agent responses.", 'success': True, 'error': None,
# 'tools_used': []}

# %%
# Test file operations
# !agentrun invoke \
    -f agent \
    --payload '{"prompt": "Write Hello from LangChain agent to a file called greeting.txt"}' \
    --verbose \
    --use-k8s
# Out:
# INFO:agentrun.services.k8s_provider:Loaded local Kubernetes config
# INFO:agentrun.services.k8s_provider:Kubernetes provider initialized for
# namespace: agentrun
# DEBUG:kubernetes.client.rest:response body:
# {"kind":"Namespace","apiVersion":"v1","metadata":{"name":"agentrun","uid":"40e8b
# dbd-a04c-4884-b7ea-7883ef65df9b","resourceVersion":"16799","creationTimestamp":"
# 2025-11-18T12:02:51Z","labels":{"kubernetes.io/metadata.name":"agentrun"},"manag
# edFields":[{"manager":"OpenAPI-Generator","operation":"Update","apiVersion":"v1"
# ,"time":"2025-11-18T12:02:51Z","fieldsType":"FieldsV1","fieldsV1":{"f:metadata":
# {"f:labels":{".":{},"f:kubernetes.io/metadata.name":{}}}}}]},"spec":{"finalizers
# ":["kubernetes"]},"status":{"phase":"Active"}}
#
# DEBUG:agentrun.services.k8s_provider:Namespace agentrun already exists
# INFO:agentrun.runtime.invoke_runtime:Starting agent invocation for workspace:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/agen
# t
# DEBUG:agentrun.services.metadata_service:Loading metadata from:
# /Users/ym/Desktop/agentcube/cmd/agentrun/03-langchain-agent-with-mcp-server/agen
# t/agent_metadata.yaml
# DEBUG:agentrun.runtime.invoke_runtime:Invocation prerequisites validated:
# agent_id=langchain-mcp-agent
# DEBUG:asyncio:Using selector: KqueueSelector
# INFO:agentrun.runtime.invoke_runtime:Invoking agent langchain-mcp-agent at
# http://localhost:32754
# INFO:agentrun.runtime.invoke_runtime:Making HTTP POST request to
# http://localhost:32754
# DEBUG:httpcore.connection:connect_tcp.started host='127.0.0.1' port=7897
# local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete
# return_value=<httpcore._backends.anyio.AnyIOStream object at 0x107744990>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request
# [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete
# return_value=(b'HTTP/1.1', 200, b'OK', [(b'Connection', b'close'),
# (b'Content-Length', b'420'), (b'Content-Type', b'application/json'), (b'Date',
# b'Thu, 27 Nov 2025 07:32:12 GMT'), (b'Server', b'uvicorn')])
# INFO:httpx:HTTP Request: POST http://localhost:32754 "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# INFO:agentrun.runtime.invoke_runtime:Agent invoked successfully:
# langchain-mcp-agent
# ⠹ Invocation completed! ✅
# ✅ Successfully invoked agent
# 📤 Response: {'response': "[Mock Mode] Received prompt: 'Write Hello from
# LangChain agent to a file called greeting.txt'. In production, this would use
# the LangChain agent with MCP tools. Available tools from MCP server: calculate,
# power, write_file, read_file, list_files, get_current_time, format_timestamp,
# server_info. Set OPENAI_API_KEY environment variable for real agent responses.",
# 'success': True, 'error': None, 'tools_used': []}

# %% [markdown]
# ## Step 14: Verify Kubernetes Deployments
#
# Let's verify both services are running properly in Kubernetes.

# %%
# Check Kubernetes pods
# !kubectl get pods -n agentrun
# Out:
# NAME                                   READY   STATUS    RESTARTS   AGE
# langchain-mcp-agent-775c8657bc-lmwnx   1/1     Running   0          68m
# mcp-utility-server-8c6578fb6-n4r6m     1/1     Running   0          105m

# %%
# Check Kubernetes services
# !kubectl get services -n agentrun
# Out:
# NAME                  TYPE       CLUSTER-IP      EXTERNAL-IP   PORT(S)          AGE
# langchain-mcp-agent   NodePort   10.96.114.200   <none>        8080:32754/TCP   68m
# mcp-utility-server    NodePort   10.111.85.177   <none>        8000:30000/TCP   105m

# %%
# Check deployments
# !kubectl get deployments -n agentrun
# Out:
# NAME                  READY   UP-TO-DATE   AVAILABLE   AGE
# langchain-mcp-agent   1/1     1            1           68m
# mcp-utility-server    1/1     1            1           105m

# %% [markdown]
# **Expected Output:**
#
# You should see:
# - 2 pods running (mcp-utility-server and langchain-mcp-agent)
# - 2 services exposed
# - 2 deployments with 1/1 replicas ready
#
# This confirms both components are deployed and running in Kubernetes.

# %% [markdown]
# ## Step 15: Understanding the Architecture
#
# ### Microservices Architecture Benefits
#
# This distributed architecture provides several advantages:
#
# **1. Separation of Concerns**
# - MCP Server: Focuses solely on providing tools
# - LangChain Agent: Focuses on orchestration and reasoning
#
# **2. Independent Scaling**
# - Scale the MCP server if tools are heavily used
# - Scale the agent if there are many user requests
# - Each component scales based on its own load
#
# **3. Reusability**
# - Multiple agents can connect to the same MCP server
# - One agent can connect to multiple MCP servers
# - Tools are centralized and reusable
#
# **4. Technology Flexibility**
# - MCP server could be written in any language
# - Agent framework can be changed without affecting tools
# - Each service can use different technology stacks
#
# **5. Fault Isolation**
# - If MCP server fails, agent can handle it gracefully
# - If agent fails, MCP server continues running
# - Independent health checks and monitoring
#
# ### MCP Protocol Benefits
#
# **Standardized Communication:**
# - Well-defined protocol for tool discovery
# - Consistent tool invocation format
# - Support for streaming and stateless operation
#
# **LangChain Integration:**
# - Seamless conversion to LangChain tools
# - Compatible with existing LangChain ecosystem
# - Works with any LangChain-compatible LLM

# %% [markdown]
# ## Step 16: Advanced Usage (Optional)
#
# ### Adding OpenAI API Key for Production Mode
#
# To use the agent in production mode with real reasoning:
#
# 1. Get an OpenAI API key from https://platform.openai.com/api-keys
# 2. Update the Kubernetes deployment with the API key:
#
# ```bash
# kubectl set env deployment/langchain-mcp-agent \
#     OPENAI_API_KEY=your-api-key-here \
#     -n agentrun
# ```
#
# 3. The agent will automatically restart and use OpenAI for reasoning
#
# ### Scaling the Services
#
# Scale the MCP server:
# ```bash
# kubectl scale deployment mcp-utility-server --replicas=3 -n agentrun
# ```
#
# Scale the agent:
# ```bash
# kubectl scale deployment langchain-mcp-agent --replicas=2 -n agentrun
# ```
#
# ### Adding More Tools to MCP Server
#
# To add new tools:
# 1. Add tool functions to `mcp_server/main.py`
# 2. Decorate with `@mcp.tool()`
# 3. Rebuild and redeploy: `agentrun build` and `agentrun publish`
# 4. Restart the agent to discover new tools

# %% [markdown]
# ## Summary and Best Practices
#
# ### What We Learned
#
# In this tutorial, we covered:
#
# 1. ✅ **Created an MCP server** with 8 utility tools
# 2. ✅ **Built a LangChain agent** that integrates with MCP server
# 3. ✅ **Deployed both services** separately to Kubernetes
# 4. ✅ **Tested the integrated system** with various tool invocations
# 5. ✅ **Understood microservices architecture** for AI agents
#
# ### Best Practices
#
# #### 1. MCP Server Design
# - **Group related tools**: Organize tools by category (calculator, file ops, etc.)
# - **Use stateless HTTP**: Required for AgentRun deployment
# - **Provide clear descriptions**: Helps agents understand tool purpose
# - **Handle errors gracefully**: Return informative error messages
# - **Keep tools focused**: Each tool should do one thing well
#
# #### 2. LangChain Agent Integration
# - **Implement mock mode**: Allows testing without API keys
# - **Cache tool discovery**: Don't rediscover tools on every request
# - **Handle connection failures**: Gracefully handle MCP server unavailability
# - **Use environment variables**: For configuration (MCP URL, API keys)
# - **Add health checks**: Monitor agent and MCP server health
#
# #### 3. Deployment
# - **Deploy services separately**: Allows independent scaling
# - **Use Kubernetes service discovery**: For service-to-service communication
# - **Set resource limits**: Prevent resource exhaustion
# - **Implement monitoring**: Track both services independently
# - **Use secrets for API keys**: Don't hardcode sensitive data
#
# #### 4. Testing
# - **Test locally first**: Before deploying to Kubernetes
# - **Test tools individually**: Verify each tool works correctly
# - **Test agent integration**: Ensure agent can call all tools
# - **Test failure scenarios**: What happens if MCP server is down?
#
# ### Common Patterns
#
# **1. Multi-Agent Systems**
# - Multiple agents sharing one MCP server
# - Reduces duplication and centralizes tools
#
# **2. Agent Chains**
# - One agent calls another agent
# - Each agent has different capabilities via different MCP servers
#
# **3. Tool Composition**
# - Multiple MCP servers providing different tool categories
# - Agent aggregates tools from multiple sources
#
# ### Next Steps
#
# Now that you understand MCP server integration, you can:
#
# 1. **Add custom tools** to the MCP server for your use case
# 2. **Create specialized agents** for different domains
# 3. **Build multi-agent systems** with shared tool infrastructure
# 4. **Implement authentication** for secure tool access
# 5. **Add observability** with logging and metrics
# 6. **Deploy to production** cloud Kubernetes clusters
#
# ### Additional Resources
#
# - [MCP Protocol Specification](https://modelcontextprotocol.io/)
# - [LangChain Documentation](https://python.langchain.com/)
# - [AgentRun CLI Documentation](../../QUICKSTART.md)
# - [FastMCP Documentation](https://github.com/modelcontextprotocol/fastmcp)
# - [AgentCube Project](https://github.com/volcano-sh/agentcube)

# %% [markdown]
# ## Cleanup (Optional)
#
# To clean up the resources created in this tutorial:

# %%
# Delete Kubernetes deployments
# !kubectl delete deployment langchain-mcp-agent -n agentrun
# !kubectl delete deployment mcp-utility-server -n agentrun

# Delete services
# !kubectl delete service langchain-mcp-agent -n agentrun
# !kubectl delete service mcp-utility-server -n agentrun

# %%
# Remove Docker images (optional)
# !docker rmi langchain-mcp-agent:latest
# !docker rmi mcp-utility-server:latest

# %%
# Remove generated files (optional)
# !rm -f agent/agent_metadata.yaml agent/Dockerfile
# !rm -f mcp_server/agent_metadata.yaml mcp_server/Dockerfile
# !rm -f .mcp_server_url.txt

# %% [markdown]
# # Congratulations! 🎉
#
# You've successfully completed the LangChain Agent with MCP Server tutorial!
#
# You now know how to:
# - ✅ Create MCP servers with custom tools
# - ✅ Integrate MCP servers with LangChain agents
# - ✅ Deploy distributed agent systems using AgentRun CLI
# - ✅ Build microservices architectures for AI agents
#
# Happy building! 🚀
